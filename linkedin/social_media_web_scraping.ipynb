# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
web="https://machinelearningmastery.com/what-is-deep-learning/"

# %%
page=requests.get(web)

# %%
text=page.content
text
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n<head><meta charset="UTF-8" /><script>if(navigator.userAgent.match(/MSIE|Internet Explorer/i)||navigator.userAgent.match(/Trident\\/7\\..*?rv:11/i)){var href=document.location.href;if(!href.match(/[?&]nowprocket/)){if(href.indexOf("?")==-1){if(href.indexOf("#")==-1){document.location.href=href+"?nowprocket=1"}else{document.location.href=href.replace("#","?nowprocket=1#")}}else{if(href.indexOf("#")==-1){document.location.href=href+"&nowprocket=1"}else{document.location.href=href.replace("#","&nowprocket=1#")}}}}</script><script>class RocketLazyLoadScripts{constructor(e){this.triggerEvents=e,this.eventOptions={passive:!0},this.userEventListener=this.triggerListener.bind(this),this.delayedScripts={normal:[],async:[],defer:[]},this.allJQueries=[]}_addUserInteractionListener(e){this.triggerEvents.forEach((t=>window.addEventListener(t,e.userEventListener,e.eventOptions)))}_removeUserInteractionListener(e){this.triggerEvents.forEach((t=>window.removeEventListener(t,e.userEventListener,e.eventOptions)))}triggerListener(){this._removeUserInteractionListener(this),"loading"===document.readyState?document.addEventListener("DOMContentLoaded",this._loadEverythingNow.bind(this)):this._loadEverythingNow()}async _loadEverythingNow(){this._delayEventListeners(),this._delayJQueryReady(this),this._handleDocumentWrite(),this._registerAllDelayedScripts(),this._preloadAllScripts(),await this._loadScriptsFromList(this.delayedScripts.normal),await this._loadScriptsFromList(this.delayedScripts.defer),await this._loadScriptsFromList(this.delayedScripts.async),await this._triggerDOMContentLoaded(),await this._triggerWindowLoad(),window.dispatchEvent(new Event("rocket-allScriptsLoaded"))}_registerAllDelayedScripts(){document.querySelectorAll("script[type=rocketlazyloadscript]").forEach((e=>{e.hasAttribute("src")?e.hasAttribute("async")&&!1!==e.async?this.delayedScripts.async.push(e):e.hasAttribute("defer")&&!1!==e.defer||"module"===e.getAttribute("data-rocket-type")?this.delayedScripts.defer.push(e):this.delayedScripts.normal.push(e):this.delayedScripts.normal.push(e)}))}async _transformScript(e){return await this._requestAnimFrame(),new Promise((t=>{const n=document.createElement("script");let r;[...e.attributes].forEach((e=>{let t=e.nodeName;"type"!==t&&("data-rocket-type"===t&&(t="type",r=e.nodeValue),n.setAttribute(t,e.nodeValue))})),e.hasAttribute("src")?(n.addEventListener("load",t),n.addEventListener("error",t)):(n.text=e.text,t()),e.parentNode.replaceChild(n,e)}))}async _loadScriptsFromList(e){const t=e.shift();return t?(await this._transformScript(t),this._loadScriptsFromList(e)):Promise.resolve()}_preloadAllScripts(){var e=document.createDocumentFragment();[...this.delayedScripts.normal,...this.delayedScripts.defer,...this.delayedScripts.async].forEach((t=>{const n=t.getAttribute("src");if(n){const t=document.createElement("link");t.href=n,t.rel="preload",t.as="script",e.appendChild(t)}})),document.head.appendChild(e)}_delayEventListeners(){let e={};function t(t,n){!function(t){function n(n){return e[t].eventsToRewrite.indexOf(n)>=0?"rocket-"+n:n}e[t]||(e[t]={originalFunctions:{add:t.addEventListener,remove:t.removeEventListener},eventsToRewrite:[]},t.addEventListener=function(){arguments[0]=n(arguments[0]),e[t].originalFunctions.add.apply(t,arguments)},t.removeEventListener=function(){arguments[0]=n(arguments[0]),e[t].originalFunctions.remove.apply(t,arguments)})}(t),e[t].eventsToRewrite.push(n)}function n(e,t){let n=e[t];Object.defineProperty(e,t,{get:()=>n||function(){},set(r){e["rocket"+t]=n=r}})}t(document,"DOMContentLoaded"),t(window,"DOMContentLoaded"),t(window,"load"),t(window,"pageshow"),t(document,"readystatechange"),n(document,"onreadystatechange"),n(window,"onload"),n(window,"onpageshow")}_delayJQueryReady(e){let t=window.jQuery;Object.defineProperty(window,"jQuery",{get:()=>t,set(n){if(n&&n.fn&&!e.allJQueries.includes(n)){n.fn.ready=n.fn.init.prototype.ready=function(t){e.domReadyFired?t.bind ...

# %%
soup = BeautifulSoup(text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head><meta charset="utf-8"/><script>if(navigator.userAgent.match(/MSIE|Internet Explorer/i)||navigator.userAgent.match(/Trident\/7\..*?rv:11/i)){var href=document.location.href;if(!href.match(/[?&]nowprocket/)){if(href.indexOf("?")==-1){if(href.indexOf("#")==-1){document.location.href=href+"?nowprocket=1"}else{document.location.href=href.replace("#","?nowprocket=1#")}}else{if(href.indexOf("#")==-1){document.location.href=href+"&nowprocket=1"}else{document.location.href=href.replace("#","&nowprocket=1#")}}}}</script><script>class RocketLazyLoadScripts{constructor(e){this.triggerEvents=e,this.eventOptions={passive:!0},this.userEventListener=this.triggerListener.bind(this),this.delayedScripts={normal:[],async:[],defer:[]},this.allJQueries=[]}_addUserInteractionListener(e){this.triggerEvents.forEach((t=>window.addEventListener(t,e.userEventListener,e.eventOptions)))}_removeUserInteractionListener(e){this.triggerEvents.forEach((t=>window.removeEventListener(t,e.userEventListener,e.eventOptions)))}triggerListener(){this._removeUserInteractionListener(this),"loading"===document.readyState?document.addEventListener("DOMContentLoaded",this._loadEverythingNow.bind(this)):this._loadEverythingNow()}async _loadEverythingNow(){this._delayEventListeners(),this._delayJQueryReady(this),this._handleDocumentWrite(),this._registerAllDelayedScripts(),this._preloadAllScripts(),await this._loadScriptsFromList(this.delayedScripts.normal),await this._loadScriptsFromList(this.delayedScripts.defer),await this._loadScriptsFromList(this.delayedScripts.async),await this._triggerDOMContentLoaded(),await this._triggerWindowLoad(),window.dispatchEvent(new Event("rocket-allScriptsLoaded"))}_registerAllDelayedScripts(){document.querySelectorAll("script[type=rocketlazyloadscript]").forEach((e=>{e.hasAttribute("src")?e.hasAttribute("async")&&!1!==e.async?this.delayedScripts.async.push(e):e.hasAttribute("defer")&&!1!==e.defer||"module"===e.getAttribute("data-rocket-type")?this.delayedScripts.defer.push(e):this.delayedScripts.normal.push(e):this.delayedScripts.normal.push(e)}))}async _transformScript(e){return await this._requestAnimFrame(),new Promise((t=>{const n=document.createElement("script");let r;[...e.attributes].forEach((e=>{let t=e.nodeName;"type"!==t&&("data-rocket-type"===t&&(t="type",r=e.nodeValue),n.setAttribute(t,e.nodeValue))})),e.hasAttribute("src")?(n.addEventListener("load",t),n.addEventListener("error",t)):(n.text=e.text,t()),e.parentNode.replaceChild(n,e)}))}async _loadScriptsFromList(e){const t=e.shift();return t?(await this._transformScript(t),this._loadScriptsFromList(e)):Promise.resolve()}_preloadAllScripts(){var e=document.createDocumentFragment();[...this.delayedScripts.normal,...this.delayedScripts.defer,...this.delayedScripts.async].forEach((t=>{const n=t.getAttribute("src");if(n){const t=document.createElement("link");t.href=n,t.rel="preload",t.as="script",e.appendChild(t)}})),document.head.appendChild(e)}_delayEventListeners(){let e={};function t(t,n){!function(t){function n(n){return e[t].eventsToRewrite.indexOf(n)>=0?"rocket-"+n:n}e[t]||(e[t]={originalFunctions:{add:t.addEventListener,remove:t.removeEventListener},eventsToRewrite:[]},t.addEventListener=function(){arguments[0]=n(arguments[0]),e[t].originalFunctions.add.apply(t,arguments)},t.removeEventListener=function(){arguments[0]=n(arguments[0]),e[t].originalFunctions.remove.apply(t,arguments)})}(t),e[t].eventsToRewrite.push(n)}function n(e,t){let n=e[t];Object.defineProperty(e,t,{get:()=>n||function(){},set(r){e["rocket"+t]=n=r}})}t(document,"DOMContentLoaded"),t(window,"DOMContentLoaded"),t(window,"load"),t(window,"pageshow"),t(document,"readystatechange"),n(document,"onreadystatechange"),n(window,"onload"),n(window,"onpageshow")}_delayJQueryReady(e){let t=window.jQuery;Object.defineProperty(window,"jQuery",{get:()=>t,set(n){if(n&&n.fn&&!e.allJQueries.includes(n)){n.fn.ready=n.fn.init.prototype.ready=function(t){e.domReadyFired?t.bind(document)(n):document.addEventListener("ro ...
# <link href="https://machinelearningmastery.com/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <script type="rocketlazyloadscript">
# MathJax = {
#   tex: {
#     inlineMath: [['$','$'],['\\(','\\)']],
#     processEscapes: true
#   },
#   options: {
#     ignoreHtmlClass: 'tex2jax_ignore|editor-rich-text'
#   }
# };
#
# </script>
# <!--  Mobile viewport scale -->
# <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=yes" name="viewport"/>
# <!-- This site is optimized with the Yoast SEO plugin v18.2 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>What is Deep Learning?</title><link data-minify="1" href="https://machinelearningmastery.com/wp-content/cache/min/1/fa06766dc51ced19bcf499cd0d50bf25.css" media="all" rel="stylesheet"/>
# <meta content="Deep Learning | Interested in learning more about deep learning and artificial neural networks? Discover exactly what deep learning is by hearing from a range of experts and leaders in the field." name="description"/>
# <link href="https://machinelearningmastery.com/what-is-deep-learning/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="What is Deep Learning?" property="og:title"/>
# <meta content="Deep Learning | Interested in learning more about deep learning and artificial neural networks? Discover exactly what deep learning is by hearing from a range of experts and leaders in the field." property="og:description"/>
# <meta content="https://machinelearningmastery.com/what-is-deep-learning/" property="og:url"/>
# <meta content="Machine Learning Mastery" property="og:site_name"/>
# <meta content="https://www.facebook.com/MachineLearningMastery/" property="article:publisher"/>
# <meta content="https://www.facebook.com/MachineLearningMastery/" property="article:author"/>
# <meta content="2019-08-15T19:00:53+00:00" property="article:published_time"/>
# <meta content="2020-08-14T00:15:26+00:00" property="article:modified_time"/>
# <meta content="https://machinelearningmastery.com/wp-content/uploads/2016/08/What-is-Deep-Learning.jpg" property="og:image"/>
# <meta content="640" property="og:image:width"/>
# <meta content="426" property="og:image:height"/>
# <meta content="image/jpeg" property="og:image:type"/>
# <meta content="Written by" name="twitter:label1"/>
# <meta content="Jason Brownlee" name="twitter:data1"/>
# <meta content="Est. reading time" name="twitter:label2"/>
# <meta content="13 minutes" name="twitter:data2"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://machinelearningmastery.com/#organization","name":"Machine Learning Mastery","url":"https://machinelearningmastery.com/","sameAs":["https://www.facebook.com/MachineLearningMastery/","https://www.linkedin.com/company/machine-learning-mastery","https://twitter.com/TeachTheMachine"],"logo":{"@type":"ImageObject","@id":"https://machinelearningmastery.com/#logo","inLanguage":"en-US","url":"https://machinelearningmastery.com/wp-content/uploads/2016/09/cropped-icon.png","contentUrl":"https://machinelearningmastery.com/wp-content/uploads/2016/09/cropped-icon.png","width":512,"height":512,"caption":"Machine Learning Mastery"},"image":{"@id":"https://machinelearningmastery.com/#logo"}},{"@type":"WebSite","@id":"https://machinelearningmastery.com/#website","url":"https://machinelearningmastery.com/","name":"Machine Learning Mastery","description":"Making developers awesome at machine learning","publisher":{"@id":"https://machinelearningmastery.com/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://machinelearningmastery.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://machinelearningmastery.com/what-is-deep-learning/#primaryimage","inLanguage":"en-US","url":"https://machinelearningmastery.com/wp-content/uploads/2016/08/What-is-Deep-Learning.jpg","contentUrl":"https://machinelearningmastery.com/wp-content/uploads/2016/08/What-is-Deep-Learning.jpg","width":640,"height":426,"caption":"What is Deep Learning? Photo by Kiran Foster, some rights reserved."},{"@type":"WebPage","@id":"https://machinelearningmastery.com/what-is-deep-learning/#webpage","url":"https://machinelearningmastery.com/what-is-deep-learning/","name":"What is Deep Learning?","isPartOf":{"@id":"https://machinelearningmastery.com/#website"},"primaryImageOfPage":{"@id":"https://machinelearningmastery.com/what-is-deep-learning/#primaryimage"},"datePublished":"2019-08-15T19:00:53+00:00","dateModified":"2020-08-14T00:15:26+00:00","description":"Deep Learning | Interested in learning more about deep learning and artificial neural networks? Discover exactly what deep learning is by hearing from a range of experts and leaders in the field.","breadcrumb":{"@id":"https://machinelearningmastery.com/what-is-deep-learning/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://machinelearningmastery.com/what-is-deep-learning/"]}]},{"@type":"BreadcrumbList","@id":"https://machinelearningmastery.com/what-is-deep-learning/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://machinelearningmastery.com/"},{"@type":"ListItem","position":2,"name":"Blog","item":"https://machinelearningmastery.com/blog/"},{"@type":"ListItem","position":3,"name":"What is Deep Learning?"}]},{"@type":"Article","@id":"https://machinelearningmastery.com/what-is-deep-learning/#article","isPartOf":{"@id":"https://machinelearningmastery.com/what-is-deep-learning/#webpage"},"author":{"@id":"https://machinelearningmastery.com/#/schema/person/e2d0ff4828d406a3b47e5a3c9a0591e8"},"headline":"What is Deep Learning?","datePublished":"2019-08-15T19:00:53+00:00","dateModified":"2020-08-14T00:15:26+00:00","mainEntityOfPage":{"@id":"https://machinelearningmastery.com/what-is-deep-learning/#webpage"},"wordCount":2585,"commentCount":287,"publisher":{"@id":"https://machinelearningmastery.com/#organization"},"image":{"@id":"https://machinelearningmastery.com/what-is-deep-learning/#primaryimage"},"thumbnailUrl":"https://machinelearningmastery.com/wp-content/uploads/2016/08/What-is-Deep-Learning.jpg","articleSection":["Deep Learning"],"inLanguage":"en-US","potentialAction":[{"@type":"CommentAction","name":"Comment","target":["https://machinelearningmastery.com/what-is- ...
# <!-- / Yoast SEO plugin. -->
# <link href="//cdn.jsdelivr.net" rel="dns-prefetch"/>
# <link href="//ads.adthrive.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//loadeu.exelator.com" rel="dns-prefetch"/>
# <link href="//sync.crwdcntrl.net" rel="dns-prefetch"/>
# <link href="//gdpr-wrapper.privacymanager.io" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//gdpr.privacymanager.io" rel="dns-prefetch"/>
# <link href="//sb.scorecardresearch.com" rel="dns-prefetch"/>
# <link href="//confiant-integrations.global.ssl.fastly.net" rel="dns-prefetch"/>
# <link href="https://feeds.feedburner.com/MachineLearningMastery" rel="alternate" title="Machine Learning Mastery » Feed" type="application/rss+xml"/>
# <link href="https://machinelearningmastery.com/comments/feed/" rel="alternate" title="Machine Learning Mastery » Comments Feed" type="application/rss+xml"/>
# <link href="https://machinelearningmastery.com/what-is-deep-learning/feed/" rel="alternate" title="Machine Learning Mastery » What is Deep Learning? Comments Feed" type="application/rss+xml"/>
# <!-- machinelearningmastery.com is managing ads with Advanced Ads 1.31.1 – https://wpadvancedads.com/ --><!--noptimize--><script id="machi-ready">
# 			window.advanced_ads_ready=function(e,a){a=a||"complete";var d=function(e){return"interactive"===a?"loading"!==e:"complete"===e};d(document.readyState)?e():document.addEventListener("readystatechange",(function(a){d(a.target.readyState)&&e()}),{once:"interactive"===a})},window.advanced_ads_ready_queue=window.advanced_ads_ready_queue||[];		</script>
# <!--/noptimize--><style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <!--[if lt IE 9]>
# <link href="https://machinelearningmastery.com/wp-content/themes/canvas-new/css/non-responsive.css" rel="stylesheet" type="text/css" />
# <style type="text/css">.col-full, #wrapper { width: 960px; max-width: 960px; } #inner-wrapper { padding: 0; } body.full-width #header, #nav-container, body.full-width #content, body.full-width #footer-widgets, body.full-width #footer { padding-left: 0; padding-right: 0; } body.fixed-mobile #top, body.fixed-mobile #header-container, body.fixed-mobile #footer-container, body.fixed-mobile #nav-container, body.fixed-mobile #footer-widgets-container { min-width: 960px; padding: 0 1em; } body.full-width #content { width: auto; padding: 0 1em;}</style>
# <![endif]-->
# <script id="jquery-core-js" src="https://machinelearningmastery.com/wp-includes/js/jquery/jquery.min.js?ver=3.6.0" type="text/javascript"></script>
# <script id="jquery-migrate-js" src="https://machinelearningmastery.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2" type="text/javascript"></script>
# <script id="urvanov_syntax_highlighter_js-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var UrvanovSyntaxHighlighterSyntaxSettings = {"version":"2.8.26","is_admin":"0","ajaxurl":"https:\/\/machinelearningmastery.com\/wp-admin\/admin-ajax.php","prefix":"urvanov-syntax-highlighter-","setting":"urvanov-syntax-highlighter-setting","selected":"urvanov-syntax-highlighter-setting-selected","changed":"urvanov-syntax-highlighter-setting-changed","special":"urvanov-syntax-highlighter-setting-special","orig_value":"data-orig-value","debug":""};
# var UrvanovSyntaxHighlighterSyntaxStrings = {"copy":"Copied to the clipboard","minimize":"Click To Expand Code"};
# /* ]]> */
# </script>
# <script data-rocket-type="text/javascript" defer="" id="urvanov_syntax_highlighter_js-js" src="https://machinelearningmastery.com/wp-content/plugins/urvanov-syntax-highlighter/js/min/urvanov_syntax_highlighter.min.js?ver=2.8.26" type="rocketlazyloadscript"></script>
# <script data-rocket-type="text/javascript" defer="" id="ssb-blocks-front-js-js" src="https://machinelearningmastery.com/wp-content/plugins/simple-social-buttons/assets/js/frontend-blocks.js?ver=4.0.0" type="rocketlazyloadscript"></script>
# <script id="ssb-front-js-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var SSB = {"ajax_url":"https:\/\/machinelearningmastery.com\/wp-admin\/admin-ajax.php","fb_share_nonce":"ad8113aee8"};
# /* ]]> */
# </script>
# <script data-minify="1" data-rocket-type="text/javascript" defer="" id="ssb-front-js-js" src="https://machinelearningmastery.com/wp-content/cache/min/1/wp-content/plugins/simple-social-buttons/assets/js/front.js?ver=1646234938" type="rocketlazyloadscript"></script>
# <script id="advanced-ads-advanced-js-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var advads_options = {"blog_id":"1","privacy":{"enabled":false,"state":"not_needed"}};
# /* ]]> */
# </script>
# <script id="advanced-ads-advanced-js-js" src="https://machinelearningmastery.com/wp-content/plugins/advanced-ads/public/assets/js/advanced.min.js?ver=1.31.1" type="text/javascript"></script>
# <script id="advanced_ads_pro/visitor_conditions-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var advanced_ads_pro_visitor_conditions = {"referrer_cookie_name":"advanced_ads_pro_visitor_referrer","referrer_exdays":"365","page_impr_cookie_name":"advanced_ads_page_impressions","page_impr_exdays":"3650"};
# /* ]]> */
# </script>
# <script id="advanced_ads_pro/visitor_conditions-js" src="https://machinelearningmastery.com/wp-content/plugins/advanced-ads-pro/modules/advanced-visitor-conditions/inc/conditions.min.js?ver=2.16.0" type="text/javascript"></script>
# <script data-rocket-type="text/javascript" defer="" id="third-party-js" src="https://machinelearningmastery.com/wp-content/themes/canvas-new/includes/js/third-party.min.js?ver=5.8.3" type="rocketlazyloadscript"></script>
# <script data-rocket-type="text/javascript" defer="" id="modernizr-js" src="https://machinelearningmastery.com/wp-content/themes/canvas-new/includes/js/modernizr.min.js?ver=2.6.2" type="rocketlazyloadscript"></script>
# <script data-rocket-type="text/javascript" defer="" id="general-js" src="https://machinelearningmastery.com/wp-content/themes/canvas-new/includes/js/general.min.js?ver=5.8.3" type="rocketlazyloadscript"></script>
# <link href="https://machinelearningmastery.com/wp-json/" rel="https://api.w.org/"/><link href="https://machinelearningmastery.com/wp-json/wp/v2/posts/3050" rel="alternate" type="application/json"/><link href="https://machinelearningmastery.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://machinelearningmastery.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <link href="https://machinelearningmastery.com/?p=3050" rel="shortlink"/>
# <link href="https://machinelearningmastery.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fmachinelearningmastery.com%2Fwhat-is-deep-learning%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://machinelearningmastery.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fmachinelearningmastery.com%2Fwhat-is-deep-learning%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <style type="text/css">.crp_title {
#     font-size: medium;
# }
# .group.portfolio-img img {
#     height: auto;
#     padding: 3px;
# 	  border: 0px solid #fff;
#     background: rgba(255,255,255,.7);
# }
# .crp_related ul li {
#     background: #fff;
#     padding: 3px;
#     margin: 0 0 1em;
#     width: 100%;
#     box-sizing: border-box;
#     -moz-box-sizing: border-box;
#     -webkit-box-sizing: border-box;
#     box-shadow: 0 0px 0px 0 rgb(0 0 0 / 18%);
#     border-radius: 3px;
#     -moz-border-radius: 3px;
#     -webkit-border-radius: 3px;
#     border: 0px solid #fff;
#     animation: wzslideup .8s ease-out,wzfadein 1s ease-out;
#     -webkit-animation: wzslideup .8s ease-out,wzfadein 1s ease-out;
#     -moz-animation: wzslideup .8s ease-out,wzfadein 1s ease;
#     font-size: 1em;
#     text-align: center;
#     display: inline-block;
# }</style> <style type="text/css">
#
#       .mpcs-classroom .nav-back i,
#       .mpcs-classroom .navbar-section a.btn,
#       .mpcs-classroom .navbar-section a,
#       .mpcs-classroom .navbar-section button {
#         color: rgba(255, 255, 255) !important;
#       }
#
#       .mpcs-classroom .navbar-section .dropdown .menu a {
#         color: rgba(44, 54, 55) !important;
#       }
#
#       .mpcs-classroom .mpcs-progress-ring {
#         background-color: rgba(29, 166, 154) !important;
#       }
#
#       .mpcs-classroom .mpcs-course-filter .dropdown .btn span,
#       .mpcs-classroom .mpcs-course-filter .dropdown .btn i,
#       .mpcs-classroom .mpcs-course-filter .input-group .input-group-btn,
#       .mpcs-classroom .mpcs-course-filter .input-group .mpcs-search,
#       .mpcs-classroom .mpcs-course-filter .input-group input[type=text],
#       .mpcs-classroom .mpcs-course-filter .dropdown a,
#       .mpcs-classroom .pagination,
#       .mpcs-classroom .pagination i,
#       .mpcs-classroom .pagination a {
#         color: rgba(44, 54, 55) !important;
#         border-color: rgba(44, 54, 55) !important;
#       }
#
#       /* body.mpcs-classroom a{
#         color: rgba();
#       } */
#
#       #mpcs-navbar,
#       #mpcs-navbar button#previous_lesson_link,
#       #mpcs-navbar button#previous_lesson_link:hover {
#         background: rgba(44, 54, 55);
#       }
#
#       .course-progress .user-progress,
#       .btn-green,
#       #mpcs-navbar button:not(#previous_lesson_link){
#         background: rgba(29, 166, 154, 0.9);
#       }
#
#       .btn-green:hover,
#       #mpcs-navbar button:not(#previous_lesson_link):focus,
#       #mpcs-navbar button:not(#previous_lesson_link):hover{
#         background: rgba(29, 166, 154);
#       }
#
#       .btn-green{border: rgba(29, 166, 154)}
#
#       .course-progress .progress-text,
#       .mpcs-lesson i.mpcs-circle-regular {
#         color: rgba(29, 166, 154)
#       }
#
#       #mpcs-main #bookmark, .mpcs-lesson.current{background: rgba(29, 166, 154, 0.3)}
#
#       .mpcs-instructor .tile-subtitle{
#         color: rgba(29, 166, 154, 1)
#       }
#
#     </style>
# <script data-rocket-type="text/javascript" type="rocketlazyloadscript">
#            var ajaxurl = "https://machinelearningmastery.com/wp-admin/admin-ajax.php";
#          </script> <style media="screen">
#
# 		.simplesocialbuttons.simplesocialbuttons_inline .ssb-fb-like {
# 	  margin: ;
# 	}
# 		 /*inline margin*/
#
#
#
#
#
#
# 			 .simplesocialbuttons.simplesocialbuttons_inline.simplesocial-simple-icons button{
# 		 margin: ;
# 	 }
#
# 			 /*margin-digbar*/
#
#
#
#
#
#
#
#
# </style>
# <!-- Open Graph Meta Tags generated by Simple Social Buttons 4.0.0 -->
# <meta content="What is Deep Learning? - Machine Learning Mastery" property="og:title"/>
# <meta content="Deep Learning is a subfield of machine learning concerned with algorithms inspired by the structure and function of the brain called artificial neural networks.
#
# If you are just starting out in the field of deep learning or you had some experience with neural networks some time ago, you may be confused. I know I was confused initially and so were many of" property="og:description"/>
# <meta content="https://machinelearningmastery.com/what-is-deep-learning/" property="og:url"/>
# <meta content="Machine Learning Mastery" property="og:site_name"/>
# <meta content="https://machinelearningmastery.com/wp-content/uploads/2016/08/What-is-Deep-Learning.jpg" property="og:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Deep Learning is a subfield of machine learning concerned with algorithms inspired by the structure and function of the brain called artificial neural networks.
#
# If you are just starting out in the field of deep learning or you had some experience with neural networks some time ago, you may be confused. I know I was confused initially and so were many of" name="twitter:description"/>
# <meta content="What is Deep Learning? - Machine Learning Mastery" name="twitter:title"/>
# <meta content="https://machinelearningmastery.com/wp-content/uploads/2016/08/What-is-Deep-Learning.jpg" property="twitter:image"/>
# <script data-rocket-type="text/javascript" type="rocketlazyloadscript">
#         var ajaxurl = 'https://machinelearningmastery.com/wp-admin/admin-ajax.php';
#     </script>
# <style id="wplmi-inline-css" type="text/css"> span.wplmi-user-avatar { width: 16px;display: inline-block !important;flex-shrink: 0; } img.wplmi-elementor-avatar { border-radius: 100%;margin-right: 3px; }
#
# </style>
# <link as="font" crossorigin="" href="https://machinelearningmastery.com/wp-content/themes/canvas-new/includes/fonts/fontawesome-webfont.woff2?v=4.5.0" rel="preload"/><script type="text/javascript">
# 		var advadsCfpQueue = [];
# 		var advadsCfpAd = function( adID ){
# 			if ( 'undefined' == typeof advadsProCfp ) { advadsCfpQueue.push( adID ) } else { advadsProCfp.addElement( adID ) }
# 		};
# 		</script>
# <!-- Custom CSS Styling -->
# <style type="text/css">
# #logo .site-title, #logo .site-description { display:none; }
# body {background-repeat:no-repeat;background-position:top left;background-attachment:scroll;border-top:0px solid #000000;}
# #header {background-repeat:no-repeat;background-position:left top;margin-top:0px;margin-bottom:0px;padding-top:10px;padding-bottom:10px;border:0px solid ;}
# #logo .site-title a {font:bold 40px/1em "Helvetica Neue", Helvetica, sans-serif;color:#222222;}
# #logo .site-description {font:normal 13px/1em "Helvetica Neue", Helvetica, sans-serif;color:#999999;}
# body, p { font:normal 14px/1.5em "Helvetica Neue", Helvetica, sans-serif;color:#555555; }
# h1 { font:bold 28px/1.2em "Helvetica Neue", Helvetica, sans-serif;color:#222222; }h2 { font:bold 24px/1.2em "Helvetica Neue", Helvetica, sans-serif;color:#222222; }h3 { font:bold 20px/1.2em "Helvetica Neue", Helvetica, sans-serif;color:#222222; }h4 { font:bold 16px/1.2em "Helvetica Neue", Helvetica, sans-serif;color:#222222; }h5 { font:bold 14px/1.2em "Helvetica Neue", Helvetica, sans-serif;color:#222222; }h6 { font:bold 12px/1.2em "Helvetica Neue", Helvetica, sans-serif;color:#222222; }
# .page-title, .post .title, .page .title {font:bold 28px/1.1em "Helvetica Neue", Helvetica, sans-serif;color:#222222;}
# .post .title a:link, .post .title a:visited, .page .title a:link, .page .title a:visited {color:#222222}
# .post-meta { font:normal 12px/1.5em "Helvetica Neue", Helvetica, sans-serif;color:#999999; }
# .entry, .entry p{ font:normal 15px/1.5em "Helvetica Neue", Helvetica, sans-serif;color:#555555; }
# .post-more {font:normal 13px/1.5em "Helvetica Neue", Helvetica, sans-serif;color:;border-top:0px solid #e6e6e6;border-bottom:0px solid #e6e6e6;}
# #post-author, #connect {border-top:1px solid #e6e6e6;border-bottom:1px solid #e6e6e6;border-left:1px solid #e6e6e6;border-right:1px solid #e6e6e6;border-radius:5px;-moz-border-radius:5px;-webkit-border-radius:5px;background-color:#fafafa}
# .nav-entries a, .woo-pagination { font:normal 13px/1em "Helvetica Neue", Helvetica, sans-serif;color:#888; }
# .woo-pagination a, .woo-pagination a:hover {color:#888!important}
# .widget h3 {font:bold 14px/1.2em "Helvetica Neue", Helvetica, sans-serif;color:#555555;border-bottom:1px solid #e6e6e6;}
# .widget_recent_comments li, #twitter li { border-color: #e6e6e6;}
# .widget p, .widget .textwidget { font:normal 13px/1.5em "Helvetica Neue", Helvetica, sans-serif;color:#555555; }
# .widget {font:normal 13px/1.5em "Helvetica Neue", Helvetica, sans-serif;color:#555555;border-radius:0px;-moz-border-radius:0px;-webkit-border-radius:0px;}
# #tabs .inside li a, .widget_woodojo_tabs .tabbable .tab-pane li a { font:bold 12px/1.5em "Helvetica Neue", Helvetica, sans-serif;color:#555555; }
# #tabs .inside li span.meta, .widget_woodojo_tabs .tabbable .tab-pane li span.meta { font:300 11px/1.5em "Helvetica Neue", Helvetica, sans-serif;color:#999999; }
# #tabs ul.wooTabs li a, .widget_woodojo_tabs .tabbable .nav-tabs li a { font:300 11px/2em "Helvetica Neue", Helvetica, sans-serif;color:#999999; }
# @media only screen and (min-width:768px) {
# ul.nav li a, #navigation ul.rss a, #navigation ul.cart a.cart-contents, #navigation .cart-contents #navigation ul.rss, #navigation ul.nav-search, #navigation ul.nav-search a { font:bold 15px/1.2em "Helvetica Neue", Helvetica, sans-serif;color:#ffffff; } #navigation ul.rss li a:before, #navigation ul.nav-search a.search-contents:before { color:#ffffff;}
# #navigation ul.nav > li a:hover, #navigation ul.nav > li:hover a, #navigation ul.nav li ul li a, #navigation ul.cart > li:hover > a, #navigation ul.cart > li > ul > div, #navigation ul.cart > li > ul > div p, #navigation ul.cart > li > ul span, #navigation ul.cart .cart_list a, #navigation ul.nav li.current_page_item a, #navigation ul.nav li.current_page_parent a, #navigation ul.nav li.current-menu-ancestor a, #navigation ul.nav li.current-cat a, #navigation ul.nav li.current-menu-item a { color:#eeeeee!important; }
# #navigation ul.nav > li a:hover, #navigation ul.nav > li:hover, #navigation ul.nav li ul, #navigation ul.cart li:hover a.cart-contents, #navigation ul.nav-search li:hover a.search-contents, #navigation ul.nav-search a.search-contents + ul, #navigation ul.cart a.cart-contents + ul, #navigation ul.nav li.current_page_item a, #navigation ul.nav li.current_page_parent a, #navigation ul.nav li.current-menu-ancestor a, #navigation ul.nav li.current-cat a, #navigation ul.nav li.current-menu-item a{background-color:#84abc7!important}
# #navigation ul.nav li ul, #navigation ul.cart > li > ul > div  { border: 0px solid #dbdbdb; }
# #navigation ul.nav > li:hover > ul  { left: 0; }
# #navigation ul.nav > li  { border-right: 0px solid #dbdbdb; }#navigation ul.nav > li:hover > ul  { left: 0; }
# #navigation { box-shadow: none; -moz-box-shadow: none; -webkit-box-shadow: none; }#navigation ul li:first-child, #navigation ul li:first-child a { border-radius:0px 0 0 0px; -moz-border-radius:0px 0 0 0px; -webkit-border-radius:0px 0 0 0px; }
# #navigation {background:#84abc7;border-top:0px solid #dbdbdb;border-bottom:0px solid #dbdbdb;border-left:0px solid #dbdbdb;border-right:0px solid #dbdbdb;border-radius:0px; -moz-border-radius:0px; -webkit-border-radius:0px;}
# #top ul.nav li a { font:normal 12px/1.6em "Helvetica Neue", Helvetica, sans-serif;color:#ddd; }
# }
# #footer, #footer p { font:normal 13px/1.4em "Helvetica Neue", Helvetica, sans-serif;color:#999999; }
# #footer {border-top:1px solid #dbdbdb;border-bottom:0px solid ;border-left:0px solid ;border-right:0px solid ;border-radius:0px; -moz-border-radius:0px; -webkit-border-radius:0px;}
# .magazine #loopedSlider .content h2.title a { font:bold 24px/1em Arial, sans-serif;color:#ffffff; }
# .wooslider-theme-magazine .slide-title a { font:bold 24px/1em Arial, sans-serif;color:#ffffff; }
# .magazine #loopedSlider .content .excerpt p { font:300 13px/1.5em Arial, sans-serif;color:#cccccc; }
# .wooslider-theme-magazine .slide-content p, .wooslider-theme-magazine .slide-excerpt p { font:300 13px/1.5em Arial, sans-serif;color:#cccccc; }
# .magazine .block .post .title a {font:bold 18px/1.2em Helvetica Neue, Helvetica, sans-serif;color:#222222; }
# #loopedSlider.business-slider .content h2 { font:bold 24px/1em Arial, sans-serif;color:#ffffff; }
# #loopedSlider.business-slider .content h2.title a { font:bold 24px/1em Arial, sans-serif;color:#ffffff; }
# .wooslider-theme-business .has-featured-image .slide-title { font:bold 24px/1em Arial, sans-serif;color:#ffffff; }
# .wooslider-theme-business .has-featured-image .slide-title a { font:bold 24px/1em Arial, sans-serif;color:#ffffff; }
# #wrapper #loopedSlider.business-slider .content p { font:300 13px/1.5em Arial, sans-serif;color:#cccccc; }
# .wooslider-theme-business .has-featured-image .slide-content p { font:300 13px/1.5em Arial, sans-serif;color:#cccccc; }
# .wooslider-theme-business .has-featured-image .slide-excerpt p { font:300 13px/1.5em Arial, sans-serif;color:#cccccc; }
# .archive_header { font:bold 18px/1em Arial, sans-serif;color:#222222; }
# .archive_header {border-bottom:1px solid #e6e6e6;}
# .archive_header .catrss { display:none; }
# </style>
# <!-- Custom Favicon -->
# <link href="https://machinelearningmastery.com/wp-content/uploads/2019/09/icon-16x16.png" rel="shortcut icon">
# <!-- Options Panel Custom CSS -->
# <style type="text/css">
# #logo img {
#    max-width: 100%;
#    height: auto;
# }
# </style>
# <!-- Woo Shortcodes CSS -->
# <!-- Custom Stylesheet -->
# <!-- Theme version -->
# <meta content="Canvas 5.9.21" name="generator"/>
# <meta content="WooFramework 6.2.9" name="generator"/>
# <script>
# window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
# ga('create', 'UA-44039733-3', 'auto',{'allowLinker': true });
# ga('require', 'linker');
# ga('linker:autoLink',['samcart.com']);
# ga('send', 'pageview');
# </script>
# <script async="" src="https://www.google-analytics.com/analytics.js"></script> <script data-rocket-type="text/javascript" type="rocketlazyloadscript">
# 			if ( typeof advadsGATracking === 'undefined' ) {
# 				window.advadsGATracking = {
# 					delayedAds: {},
# 					deferedAds: {}
# 				};
# 			}
# 		</script>
# <link href="https://machinelearningmastery.com/wp-content/uploads/2016/09/cropped-icon-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://machinelearningmastery.com/wp-content/uploads/2016/09/cropped-icon-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://machinelearningmastery.com/wp-content/uploads/2016/09/cropped-icon-180x180.png" rel="apple-touch-icon"/>
# <meta content="https://machinelearningmastery.com/wp-content/uploads/2016/09/cropped-icon-270x270.png" name="msapplication-TileImage"/>
# <style id="wp-custom-css" type="text/css">
# 			.display-posts-listing.image-left .listing-item {
# 	overflow: hidden;
# 	margin-bottom: 30px;
# 	width: 100%;
# }
#
# .display-posts-listing.image-left .image {
# 	float: left;
# 	margin: 0 10px 0 0;
# }
#
# .display-posts-listing.image-left .attachment-thumbnail {
# 	height: auto;
# 	width: auto;
# 	max-width: 50px;
# 	max-height: 50px;
# 	border-radius: 50%;
# }
#
# .display-posts-listing.image-left .title {
# 	display: block;
# }
#
# .display-posts-listing.image-left .excerpt-dash {
# 	display: none;
# }
#
# .display-posts-listing.image-left {
# 	margin: 0 0 40px 0;
# }		</style>
# <noscript><style id="rocket-lazyload-nojs-css">.rll-youtube-player, [data-lazy-src]{display:none !important;}</style></noscript> <!-- Facebook Pixel Code -->
# <script type="rocketlazyloadscript">
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window, document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '834324500844861');
# fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=834324500844861&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# </link></head>
# <body class="post-template-default single single-post postid-3050 single-format-standard gecko alt-style-default two-col-left width-960 two-col-left-960 aa-prefix-machi-">
# <div id="wrapper">
# <div id="inner-wrapper">
# <h3 class="nav-toggle icon"><a href="#navigation">Navigation</a></h3>
# <header class="col-full" id="header">
# <div id="logo">
# <a href="https://machinelearningmastery.com/" title="Making developers awesome at machine learning"><img alt="Machine Learning Mastery" height="80" src="https://machinelearningmastery.com/wp-content/uploads/2019/09/Header_smaller_text_better-1.png" width="480"/></a>
# <span class="site-title"><a href="https://machinelearningmastery.com/">Machine Learning Mastery</a></span>
# <span class="site-description">Making developers awesome at machine learning</span>
# </div>
# <div class="header-widget">
# <div class="widget_text widget widget_custom_html" id="custom_html-99"><div class="textwidget custom-html-widget"></div></div><div class="widget_text widget widget_custom_html" id="custom_html-40"><div class="textwidget custom-html-widget"><div style="text-align: right;">
# <script async="" defer="" src="https://embed.lpcontent.net/leadboxes/current/embed.js" type="rocketlazyloadscript"></script> <a data-leadbox-domain="machinelearningmastery.lpages.co" data-leadbox-popup="bTgS4zh2NqPUjtGrRXTwLh" href="">Click to Take the FREE Deep Learning Crash-Course</a>
# </div></div></div><div class="widget widget_search" id="search-4"><div class="search_main">
# <form action="https://machinelearningmastery.com/" class="searchform" method="get">
# <input class="field s" name="s" onblur="if (this.value == '') {this.value = 'Search...';}" onfocus="if (this.value == 'Search...') {this.value = '';}" type="text" value="Search..."/>
# <input name="post_type" type="hidden" value="post"/>
# <button class="fa fa-search submit" name="submit" type="submit" value="Search"></button>
# </form>
# <div class="fix"></div>
# </div></div> </div>
# </header>
# <nav class="col-full" id="navigation" role="navigation">
# <section class="menus">
# <a class="nav-home" href="https://machinelearningmastery.com"><span>Home</span></a>
# <h3>Main Menu</h3><ul class="nav fl" id="main-nav"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6503" id="menu-item-6503"><a href="https://machinelearningmastery.com/start-here/">Get Started</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current_page_parent menu-item-6501" id="menu-item-6501"><a href="https://machinelearningmastery.com/blog/">Blog</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-6506" id="menu-item-6506"><a href="#">Topics</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent menu-item-6508" id="menu-item-6508"><a href="https://machinelearningmastery.com/category/deep-learning/">Deep Learning (keras)</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-7921" id="menu-item-7921"><a href="https://machinelearningmastery.com/category/deep-learning-for-computer-vision/">Computer Vision</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6509" id="menu-item-6509"><a href="https://machinelearningmastery.com/category/deep-learning-time-series/">Neural Net Time Series</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6515" id="menu-item-6515"><a href="https://machinelearningmastery.com/category/natural-language-processing/">NLP (Text)</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-8576" id="menu-item-8576"><a href="https://machinelearningmastery.com/category/generative-adversarial-networks/">GANs</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6511" id="menu-item-6511"><a href="https://machinelearningmastery.com/category/lstm/">LSTMs</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-7106" id="menu-item-7106"><a href="https://machinelearningmastery.com/category/better-deep-learning/">Better Deep Learning</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6512" id="menu-item-6512"><a href="https://machinelearningmastery.com/category/machine-learning-algorithms/">Intro to Algorithms</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6507" id="menu-item-6507"><a href="https://machinelearningmastery.com/category/algorithms-from-scratch/">Code Algorithms</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6520" id="menu-item-6520"><a href="https://machinelearningmastery.com/category/time-series/">Intro to Time Series</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6516" id="menu-item-6516"><a href="https://machinelearningmastery.com/category/python-machine-learning/">Python (scikit-learn)</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-11055" id="menu-item-11055"><a href="https://machinelearningmastery.com/category/ensemble-learning/">Ensemble Learning</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-9966" id="menu-item-9966"><a href="https://machinelearningmastery.com/category/imbalanced-classification/">Imbalanced Learning</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-10674" id="menu-item-10674"><a href="https://machinelearningmastery.com/category/data-preparation/">Data Preparation</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6517" id="menu-item-6517"><a href="https://machinelearningmastery.com/category/r-machine-learning/">R (caret)</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6522" id="menu-item-6522"><a href="https://machinelearningmastery.com/category/weka-machine-learning/">Weka (no code)</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6510" id="menu-item-6510"><a href="https://machinelearningmastery.com/category/linear-algebra/">Linear Algebra</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6519" id="menu-item-6519"><a href="https://machinelearningmastery.com/category/statistical-methods/">Statistics</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-12825" id="menu-item-12825"><a href="https://machinelearningmastery.com/category/optimization/">Optimization</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-8989" id="menu-item-8989"><a href="https://machinelearningmastery.com/category/probability/">Probability</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-6523" id="menu-item-6523"><a href="https://machinelearningmastery.com/category/xgboost/">XGBoost</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6502" id="menu-item-6502"><a href="https://machinelearningmastery.com/products/">EBooks</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6500" id="menu-item-6500"><a href="https://machinelearningmastery.com/faq/">FAQ</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6504" id="menu-item-6504"><a href="https://machinelearningmastery.com/about/">About</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6505" id="menu-item-6505"><a href="https://machinelearningmastery.com/contact/">Contact</a></li>
# </ul> <div class="side-nav">
# </div><!-- /#side-nav -->
# </section><!-- /.menus -->
# <a class="nav-close" href="#top"><span>Return to Content</span></a>
# </nav>
# <div style="width:100%; min-height:100px; padding-top:10px; padding-bottom:50px; float:center;">
# <div class="machi-80075cf63eb314f5a42148103d907d48 machi-header" id="machi-80075cf63eb314f5a42148103d907d48"></div></div>
# <!-- #content Starts -->
# <div class="col-full" id="content">
# <div id="main-sidebar-container">
# <!-- #main Starts -->
# <section id="main">
# <article class="post-3050 post type-post status-publish format-standard has-post-thumbnail hentry category-deep-learning">
# <header>
# <h1 class="title entry-title">What is Deep Learning?</h1> </header>
# <div class="post-meta"><span class="small">By</span> <span class="author vcard"><span class="fn"><a href="https://machinelearningmastery.com/author/jasonb/" rel="author" title="Posts by Jason Brownlee">Jason Brownlee</a></span></span> <span class="small">on</span> <abbr class="date time published updated" title="2019-08-16T05:00:53+1000">August 16, 2019</abbr> <span class="small">in</span> <span class="categories"><a href="https://machinelearningmastery.com/category/deep-learning/" title="View all items in Deep Learning">Deep Learning</a></span> </div>
# <section class="entry">
# <div class="simplesocialbuttons simplesocial-simple-icons simplesocialbuttons_inline simplesocialbuttons-align-left post-3050 post simplesocialbuttons-inline-no-animation">
# <button class="ssb_tweet-icon" data-href="https://twitter.com/share?text=What+is+Deep+Learning%3F&amp;url=https://machinelearningmastery.com/what-is-deep-learning/" onclick="javascript:window.open(this.dataset.href, '', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;" rel="nofollow">
# <span class="icon"><svg viewbox="0 0 72 72" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h72v72H0z" fill="none"></path><path class="icon" d="M68.812 15.14c-2.348 1.04-4.87 1.744-7.52 2.06 2.704-1.62 4.78-4.186 5.757-7.243-2.53 1.5-5.33 2.592-8.314 3.176C56.35 10.59 52.948 9 49.182 9c-7.23 0-13.092 5.86-13.092 13.093 0 1.026.118 2.02.338 2.98C25.543 24.527 15.9 19.318 9.44 11.396c-1.125 1.936-1.77 4.184-1.77 6.58 0 4.543 2.312 8.552 5.824 10.9-2.146-.07-4.165-.658-5.93-1.64-.002.056-.002.11-.002.163 0 6.345 4.513 11.638 10.504 12.84-1.1.298-2.256.457-3.45.457-.845 0-1.666-.078-2.464-.23 1.667 5.2 6.5 8.985 12.23 9.09-4.482 3.51-10.13 5.605-16.26 5.605-1.055 0-2.096-.06-3.122-.184 5.794 3.717 12.676 5.882 20.067 5.882 24.083 0 37.25-19.95 37.25-37.25 0-.565-.013-1.133-.038-1.693 2.558-1.847 4.778-4.15 6.532-6.774z" fill="#fff"></path></svg></span><i class="simplesocialtxt">Tweet </i></button>
# <button class="ssb_tweet-icon" data-href="https://twitter.com/share?text=What+is+Deep+Learning%3F&amp;url=https://machinelearningmastery.com/what-is-deep-learning/" onclick="javascript:window.open(this.dataset.href, '', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;" rel="nofollow">
# <span class="icon"><svg viewbox="0 0 72 72" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h72v72H0z" fill="none"></path><path class="icon" d="M68.812 15.14c-2.348 1.04-4.87 1.744-7.52 2.06 2.704-1.62 4.78-4.186 5.757-7.243-2.53 1.5-5.33 2.592-8.314 3.176C56.35 10.59 52.948 9 49.182 9c-7.23 0-13.092 5.86-13.092 13.093 0 1.026.118 2.02.338 2.98C25.543 24.527 15.9 19.318 9.44 11.396c-1.125 1.936-1.77 4.184-1.77 6.58 0 4.543 2.312 8.552 5.824 10.9-2.146-.07-4.165-.658-5.93-1.64-.002.056-.002.11-.002.163 0 6.345 4.513 11.638 10.504 12.84-1.1.298-2.256.457-3.45.457-.845 0-1.666-.078-2.464-.23 1.667 5.2 6.5 8.985 12.23 9.09-4.482 3.51-10.13 5.605-16.26 5.605-1.055 0-2.096-.06-3.122-.184 5.794 3.717 12.676 5.882 20.067 5.882 24.083 0 37.25-19.95 37.25-37.25 0-.565-.013-1.133-.038-1.693 2.558-1.847 4.778-4.15 6.532-6.774z" fill="#fff"></path></svg></span><i class="simplesocialtxt">Tweet </i></button> <button class="ssb_fbshare-icon" data-href="https://www.facebook.com/sharer/sharer.php?u=https://machinelearningmastery.com/what-is-deep-learning/" onclick="javascript:window.open(this.dataset.href, '', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;" target="_blank">
# <span class="icon"><svg class="_1pbq" color="#ffffff" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path class="icon" d="M8 14H3.667C2.733 13.9 2 13.167 2 12.233V3.667A1.65 1.65 0 0 1 3.667 2h8.666A1.65 1.65 0 0 1 14 3.667v8.566c0 .934-.733 1.667-1.667 1.767H10v-3.967h1.3l.7-2.066h-2V6.933c0-.466.167-.9.867-.9H12v-1.8c.033 0-.933-.266-1.533-.266-1.267 0-2.434.7-2.467 2.133v1.867H6v2.066h2V14z" fill="#ffffff" fill-rule="evenodd"></path></svg></span>
# <span class="simplesocialtxt">Share </span> </button>
# <button class="ssb_linkedin-icon" data-href="https://www.linkedin.com/cws/share?url=https://machinelearningmastery.com/what-is-deep-learning/" onclick="javascript:window.open(this.dataset.href, '', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;">
# <span class="icon"> <svg enable-background="new -301.4 387.5 15 14.1" height="14.1px" id="Layer_1" version="1.1" viewbox="-301.4 387.5 15 14.1" width="15px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"> <g id="XMLID_398_"> <path d="M-296.2,401.6c0-3.2,0-6.3,0-9.5h0.1c1,0,2,0,2.9,0c0.1,0,0.1,0,0.1,0.1c0,0.4,0,0.8,0,1.2 c0.1-0.1,0.2-0.3,0.3-0.4c0.5-0.7,1.2-1,2.1-1.1c0.8-0.1,1.5,0,2.2,0.3c0.7,0.4,1.2,0.8,1.5,1.4c0.4,0.8,0.6,1.7,0.6,2.5 c0,1.8,0,3.6,0,5.4v0.1c-1.1,0-2.1,0-3.2,0c0-0.1,0-0.1,0-0.2c0-1.6,0-3.2,0-4.8c0-0.4,0-0.8-0.2-1.2c-0.2-0.7-0.8-1-1.6-1 c-0.8,0.1-1.3,0.5-1.6,1.2c-0.1,0.2-0.1,0.5-0.1,0.8c0,1.7,0,3.4,0,5.1c0,0.2,0,0.2-0.2,0.2c-1,0-1.9,0-2.9,0 C-296.1,401.6-296.2,401.6-296.2,401.6z" fill="#FFFFFF" id="XMLID_399_"></path> <path d="M-298,401.6L-298,401.6c-1.1,0-2.1,0-3,0c-0.1,0-0.1,0-0.1-0.1c0-3.1,0-6.1,0-9.2 c0-0.1,0-0.1,0.1-0.1c1,0,2,0,2.9,0h0.1C-298,395.3-298,398.5-298,401.6z" fill="#FFFFFF" id="XMLID_400_"></path> <path d="M-299.6,390.9c-0.7-0.1-1.2-0.3-1.6-0.8c-0.5-0.8-0.2-2.1,1-2.4c0.6-0.2,1.2-0.1,1.8,0.2 c0.5,0.4,0.7,0.9,0.6,1.5c-0.1,0.7-0.5,1.1-1.1,1.3C-299.1,390.8-299.4,390.8-299.6,390.9L-299.6,390.9z" fill="#FFFFFF" id="XMLID_401_"></path> </g> </svg> </span>
# <span class="simplesocialtxt">Share</span> </button>
# </div>
# <p id="last-modified-info">Last Updated on August 14, 2020</p>
# <p><strong>Deep Learning</strong> is a subfield of machine learning concerned with algorithms inspired by the structure and function of the brain called <strong>artificial neural networks</strong>.</p>
# ...
# <script data-cfasync="false" data-rocket-type="text/javascript" type="rocketlazyloadscript">
#   var _dcq = _dcq || [];
#   var _dcs = _dcs || {};
#   _dcs.account = '9556588';
#
#   (function() {
#     var dc = document.createElement('script');
#     dc.type = 'text/javascript'; dc.async = true;
#     dc.src = '//tag.getdrip.com/9556588.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(dc, s);
#   })();
# </script>
# <!-- end Drip --><script data-rocket-type="text/javascript" defer="" id="comment-reply-js" src="https://machinelearningmastery.com/wp-includes/js/comment-reply.min.js?ver=5.8.3" type="rocketlazyloadscript"></script>
# <script data-minify="1" data-rocket-type="text/javascript" defer="" id="mathjax-js" src="https://machinelearningmastery.com/wp-content/cache/min/1/npm/mathjax@3/es5/tex-chtml.js?ver=1646234939" type="rocketlazyloadscript"></script>
# <script data-rocket-type="text/javascript" id="rocket-browser-checker-js-after" type="rocketlazyloadscript">
# "use strict";var _createClass=function(){function defineProperties(target,props){for(var i=0;i<props.length;i++){var descriptor=props[i];descriptor.enumerable=descriptor.enumerable||!1,descriptor.configurable=!0,"value"in descriptor&&(descriptor.writable=!0),Object.defineProperty(target,descriptor.key,descriptor)}}return function(Constructor,protoProps,staticProps){return protoProps&&defineProperties(Constructor.prototype,protoProps),staticProps&&defineProperties(Constructor,staticProps),Constructor}}();function _classCallCheck(instance,Constructor){if(!(instance instanceof Constructor))throw new TypeError("Cannot call a class as a function")}var RocketBrowserCompatibilityChecker=function(){function RocketBrowserCompatibilityChecker(options){_classCallCheck(this,RocketBrowserCompatibilityChecker),this.passiveSupported=!1,this._checkPassiveOption(this),this.options=!!this.passiveSupported&&options}return _createClass(RocketBrowserCompatibilityChecker,[{key:"_checkPassiveOption",value:function(self){try{var options={get passive(){return!(self.passiveSupported=!0)}};window.addEventListener("test",null,options),window.removeEventListener("test",null,options)}catch(err){self.passiveSupported=!1}}},{key:"initRequestIdleCallback",value:function(){!1 in window&&(window.requestIdleCallback=function(cb){var start=Date.now();return setTimeout(function(){cb({didTimeout:!1,timeRemaining:function(){return Math.max(0,50-(Date.now()-start))}})},1)}),!1 in window&&(window.cancelIdleCallback=function(id){return clearTimeout(id)})}},{key:"isDataSaverModeOn",value:function(){return"connection"in navigator&&!0===navigator.connection.saveData}},{key:"supportsLinkPrefetch",value:function(){var elem=document.createElement("link");return elem.relList&&elem.relList.supports&&elem.relList.supports("prefetch")&&window.IntersectionObserver&&"isIntersecting"in IntersectionObserverEntry.prototype}},{key:"isSlowConnection",value:function(){return"connection"in navigator&&"effectiveType"in navigator.connection&&("2g"===navigator.connection.effectiveType||"slow-2g"===navigator.connection.effectiveType)}}]),RocketBrowserCompatibilityChecker}();
# </script>
# <script id="rocket-preload-links-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var RocketPreloadLinksConfig = {"excludeUris":"\/register\/machine-learning-university\/|\/courses\/\/lessons\/holding-back-goals\/|\/courses\/course-get-started\/|\/courses\/course-get-started\/lessons\/holding-back-goals\/|\/courses\/course-get-started\/lessons\/why-machine-learning-does-not-have-to-be-so-hard\/|\/courses\/course-get-started\/lessons\/how-to-think-about-machine-learning\/|\/courses\/course-get-started\/lessons\/find-your-machine-learning-tribe\/|\/courses\/step-by-step-process\/|\/courses\/probability-for-machine-learning\/|\/account\/|\/register\/|\/courses\/|\/machine-learning-mastery-university-registration\/|\/register\/|\/newsletter\/|\/(?:.+\/)?feed(?:\/(?:.+\/?)?)?$|\/(?:.+\/)?embed\/|\/(index\\.php\/)?wp\\-json(\/.*|$)|\/wp-admin\/|\/logout\/|\/login\/|\/refer\/|\/go\/|\/recommend\/|\/recommends\/","usesTrailingSlash":"1","imageExt":"jpg|jpeg|gif|png|tiff|bmp|webp|avif","fileExt":"jpg|jpeg|gif|png|tiff|bmp|webp|avif|php|pdf|html|htm","siteUrl":"https:\/\/machinelearningmastery.com","onHoverDelay":"100","rateThrottle":"3"};
# /* ]]> */
# </script>
# <script data-rocket-type="text/javascript" id="rocket-preload-links-js-after" type="rocketlazyloadscript">
# (function() {
# "use strict";var r="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(e){return typeof e}:function(e){return e&&"function"==typeof Symbol&&e.constructor===Symbol&&e!==Symbol.prototype?"symbol":typeof e},e=function(){function i(e,t){for(var n=0;n<t.length;n++){var i=t[n];i.enumerable=i.enumerable||!1,i.configurable=!0,"value"in i&&(i.writable=!0),Object.defineProperty(e,i.key,i)}}return function(e,t,n){return t&&i(e.prototype,t),n&&i(e,n),e}}();function i(e,t){if(!(e instanceof t))throw new TypeError("Cannot call a class as a function")}var t=function(){function n(e,t){i(this,n),this.browser=e,this.config=t,this.options=this.browser.options,this.prefetched=new Set,this.eventTime=null,this.threshold=1111,this.numOnHover=0}return e(n,[{key:"init",value:function(){!this.browser.supportsLinkPrefetch()||this.browser.isDataSaverModeOn()||this.browser.isSlowConnection()||(this.regex={excludeUris:RegExp(this.config.excludeUris,"i"),images:RegExp(".("+this.config.imageExt+")$","i"),fileExt:RegExp(".("+this.config.fileExt+")$","i")},this._initListeners(this))}},{key:"_initListeners",value:function(e){-1<this.config.onHoverDelay&&document.addEventListener("mouseover",e.listener.bind(e),e.listenerOptions),document.addEventListener("mousedown",e.listener.bind(e),e.listenerOptions),document.addEventListener("touchstart",e.listener.bind(e),e.listenerOptions)}},{key:"listener",value:function(e){var t=e.target.closest("a"),n=this._prepareUrl(t);if(null!==n)switch(e.type){case"mousedown":case"touchstart":this._addPrefetchLink(n);break;case"mouseover":this._earlyPrefetch(t,n,"mouseout")}}},{key:"_earlyPrefetch",value:function(t,e,n){var i=this,r=setTimeout(function(){if(r=null,0===i.numOnHover)setTimeout(function(){return i.numOnHover=0},1e3);else if(i.numOnHover>i.config.rateThrottle)return;i.numOnHover++,i._addPrefetchLink(e)},this.config.onHoverDelay);t.addEventListener(n,function e(){t.removeEventListener(n,e,{passive:!0}),null!==r&&(clearTimeout(r),r=null)},{passive:!0})}},{key:"_addPrefetchLink",value:function(i){return this.prefetched.add(i.href),new Promise(function(e,t){var n=document.createElement("link");n.rel="prefetch",n.href=i.href,n.onload=e,n.onerror=t,document.head.appendChild(n)}).catch(function(){})}},{key:"_prepareUrl",value:function(e){if(null===e||"object"!==(void 0===e?"undefined":r(e))||!1 in e||-1===["http:","https:"].indexOf(e.protocol))return null;var t=e.href.substring(0,this.config.siteUrl.length),n=this._getPathname(e.href,t),i={original:e.href,protocol:e.protocol,origin:t,pathname:n,href:t+n};return this._isLinkOk(i)?i:null}},{key:"_getPathname",value:function(e,t){var n=t?e.substring(this.config.siteUrl.length):e;return n.startsWith("/")||(n="/"+n),this._shouldAddTrailingSlash(n)?n+"/":n}},{key:"_shouldAddTrailingSlash",value:function(e){return this.config.usesTrailingSlash&&!e.endsWith("/")&&!this.regex.fileExt.test(e)}},{key:"_isLinkOk",value:function(e){return null!==e&&"object"===(void 0===e?"undefined":r(e))&&(!this.prefetched.has(e.href)&&e.origin===this.config.siteUrl&&-1===e.href.indexOf("?")&&-1===e.href.indexOf("#")&&!this.regex.excludeUris.test(e.href)&&!this.regex.images.test(e.href))}}],[{key:"run",value:function(){"undefined"!=typeof RocketPreloadLinksConfig&&new n(new RocketBrowserCompatibilityChecker({capture:!0,passive:!0}),RocketPreloadLinksConfig).init()}}]),n}();t.run();
# }());
# </script>
# <script id="advanced-ads-pro/front-js" src="https://machinelearningmastery.com/wp-content/plugins/advanced-ads-pro/assets/js/advanced-ads-pro.min.js?ver=2.16.0" type="text/javascript"></script>
# <script id="q2w3_fixed_widget-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var q2w3_sidebar_options = [{"sidebar":"primary","use_sticky_position":false,"margin_top":10,"margin_bottom":0,"stop_elements_selectors":"","screen_max_width":400,"screen_max_height":0,"widgets":["#custom_html-89","#custom_html-50","#custom_html-90","#custom_html-91","#custom_html-58","#custom_html-60","#custom_html-59","#custom_html-84","#custom_html-51","#custom_html-56","#custom_html-55","#custom_html-57","#custom_html-53","#custom_html-54","#custom_html-52","#custom_html-48","#custom_html-49","#custom_html-80","#custom_html-47","#custom_html-85","#custom_html-30","#custom_html-29","#custom_html-28","#custom_html-27","#custom_html-3","#custom_html-24","#custom_html-23","#custom_html-22","#custom_html-21","#custom_html-20","#custom_html-19","#custom_html-18","#custom_html-17","#custom_html-16","#custom_html-15","#custom_html-14","#custom_html-13","#custom_html-11","#custom_html-10","#custom_html-5","#custom_html-9","#custom_html-61","#custom_html-81","#custom_html-86","#custom_html-92","#custom_html-97"]}];
# /* ]]> */
# </script>
# <script data-rocket-type="text/javascript" defer="" id="q2w3_fixed_widget-js" src="https://machinelearningmastery.com/wp-content/plugins/q2w3-fixed-widget/js/frontend.min.js?ver=6.0.4" type="rocketlazyloadscript"></script>
# <script id="advanced-ads-pro/cache_busting-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var advanced_ads_pro_ajax_object = {"ajax_url":"https:\/\/machinelearningmastery.com\/wp-admin\/admin-ajax.php","lazy_load_module_enabled":"","lazy_load":{"default_offset":0,"offsets":[]},"moveintohidden":"","wp_timezone_offset":"39600"};
# /* ]]> */
# </script>
# <script id="advanced-ads-pro/cache_busting-js" src="https://machinelearningmastery.com/wp-content/plugins/advanced-ads-pro/assets/js/base.min.js?ver=2.16.0" type="text/javascript"></script>
# <script id="advadsTrackingScript-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var advadsTracking = {"impressionActionName":"aatrack-records","clickActionName":"aatrack-click","targetClass":"machi-target","blogId":"1"};
# /* ]]> */
# </script>
# <script id="advadsTrackingScript-js" src="https://machinelearningmastery.com/wp-content/plugins/advanced-ads-tracking/public/assets/js/dist/tracking.min.js?ver=2.2.0" type="text/javascript"></script>
# <script id="advadsTrackingGAFront-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var advadsGALocale = {"Impressions":"Impressions","Clicks":"Clicks"};
# /* ]]> */
# </script>
# <script id="advadsTrackingGAFront-js" src="https://machinelearningmastery.com/wp-content/plugins/advanced-ads-tracking/public/assets/js/dist/ga-tracking.min.js?ver=2.2.0" type="text/javascript"></script>
# <script defer="" id="wp-embed-js" src="https://machinelearningmastery.com/wp-includes/js/wp-embed.min.js?ver=5.8.3" type="text/javascript"></script>
# <!--noptimize--><script type="rocketlazyloadscript">window.advads_admin_bar_items = [];</script><!--/noptimize--><!--noptimize--><script>window.advads_ajax_queries = [{"id":"header","method":"placement","params":{"previous_method":"placement","previous_id":"header","post":"r0","url_parameter":"\/what-is-deep-learning\/","placement_type":"default","placement_position":"center","inline-css":"","placement_conditions":{"display":{"0":{"type":"posttypes","operator":"is","value":["post"]},"1":{"type":"page_template","operator":"is_not","value":["template-archives.php","template-biz.php","template-blog.php","template-contact.php","template-imagegallery.php","template-magazine.php","template-portfolio.php","template-sitemap.php","template-timeline.php","template-widgets.php"]},"3":{"type":"request_uri","operator":"contain_not","value":"\/blog\/"},"4":{"type":"request_uri","operator":"contain_not","value":"\/category\/"}},"visitors":[{"type":"mobile","operator":"is_not"}]},"cache-busting":"auto","output":{"class":["machi-header"],"placement_id":"header"}},"elementid":"machi-80075cf63eb314f5a42148103d907d48","blog_id":1}];
# window.advads_ajax_queries_args = {"r0":{"id":3050,"author":"1","post_type":"post"}};
# ( window.advanced_ads_ready || jQuery( document ).ready ).call( null, function() {if ( !window.advanced_ads_pro ) {console.log("Advanced Ads Pro: cache-busting can not be initialized");} });</script><!--/noptimize--><script data-rocket-type="text/javascript" type="rocketlazyloadscript">function initTwitCount(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://static1.twitcount.com/js/twitcount.js';fjs.parentNode.insertBefore(js,fjs)}}
#         var ssb_twit_count_init=!1;addEventListener('mouseover',function(event){if(!ssb_twit_count_init){initTwitCount(document,'script','twitcount_plugins')
#         ssb_twit_count_init=!0}})</script><!--noptimize--><script>!function(){window.advanced_ads_ready_queue=window.advanced_ads_ready_queue||[],advanced_ads_ready_queue.push=window.advanced_ads_ready;for(var d=0,a=advanced_ads_ready_queue.length;d<a;d++)advanced_ads_ready(advanced_ads_ready_queue[d])}();</script><!--/noptimize--><script id="machi-tracking">var advads_tracking_ads = {};var advads_tracking_urls = {"1":"https:\/\/machinelearningmastery.com\/wp-admin\/admin-ajax.php"};var advads_tracking_methods = {"1":"ga"};var advads_tracking_parallel = {"1":false};var advads_tracking_linkbases = {"1":"https:\/\/machinelearningmastery.com\/linkout\/"};var advads_gatracking_uids = {"1":"UA-44039733-3"};var advads_gatracking_allads = {"1":{"13283":{"title":"pace mar2022","target":"https:\/\/online.pace.edu\/online-data-science\/?cid=2734&utm_source=machinelearningmastery&utm_medium=display&utm_campaign=machinelearningmastery","impression":true,"click":true}}};var advads_gatracking_anonym = false;var advads_gatracking_transmitpageqs = {};</script><script>window.lazyLoadOptions={elements_selector:"iframe[data-lazy-src]",data_src:"lazy-src",data_srcset:"lazy-srcset",data_sizes:"lazy-sizes",class_loading:"lazyloading",class_loaded:"lazyloaded",threshold:300,callback_loaded:function(element){if(element.tagName==="IFRAME"&&element.dataset.rocketLazyload=="fitvidscompatible"){if(element.classList.contains("lazyloaded")){if(typeof window.jQuery!="undefined"){if(jQuery.fn.fitVids){jQuery(element).parent().fitVids()}}}}}};window.addEventListener('LazyLoad::Initialized',function(e){var lazyLoadInstance=e.detail.instance;if(window.MutationObserver){var observer=new MutationObserver(function(mutations){var image_count=0;var iframe_count=0;var rocketlazy_count=0;mutations.forEach(function(mutation){for(var i=0;i<mutation.addedNodes.length;i++){if(typeof mutation.addedNodes[i].getElementsByTagName!=='function'){continue}
# if(typeof mutation.addedNodes[i].getElementsByClassName!=='function'){continue}
# images=mutation.addedNodes[i].getElementsByTagName('img');is_image=mutation.addedNodes[i].tagName=="IMG";iframes=mutation.addedNodes[i].getElementsByTagName('iframe');is_iframe=mutation.addedNodes[i].tagName=="IFRAME";rocket_lazy=mutation.addedNodes[i].getElementsByClassName('rocket-lazyload');image_count+=images.length;iframe_count+=iframes.length;rocketlazy_count+=rocket_lazy.length;if(is_image){image_count+=1}
# if(is_iframe){iframe_count+=1}}});if(image_count>0||iframe_count>0||rocketlazy_count>0){lazyLoadInstance.update()}});var b=document.getElementsByTagName("body")[0];var config={childList:!0,subtree:!0};observer.observe(b,config)}},!1)</script><script async="" data-no-minify="1" src="https://machinelearningmastery.com/wp-content/plugins/wp-rocket/assets/js/lazyload/17.5/lazyload.min.js"></script></body>
# </html>
# <!-- This website is like a Rocket, isn't it? Performance optimized by WP Rocket. Learn more: https://wp-rocket.me -->

# %%
products=soup.find_all('span',attrs={'class':'name'})
comments=soup.find_all('div',attrs={'class':'comment-entry'})
#price=soup.find_all('strike',attrs={'class':'original-price'})
#ratings=soup.find_all('span',attrs={'class':'c3XbGJ'})

# %%
print(products)
# Out:
# [<span class="name">Gibachan</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Priyankar</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Roman</span>, <span class="name">sk</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Rita</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Tooba</span>, <span class="name">Swapnil Pote</span>, <span class="name">Ibrahim Amer</span>, <span class="name">Dudley Jude</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Ali</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name"><a class="url" href="https://www.simplilearn.com" rel="external nofollow ugc">Mike Rauner</a></span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Alan Beckles MD MS</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Alan Beckles MD MS</span>, <span class="name"><a class="url" href="http://www.machinelearningmentor.com" rel="external nofollow ugc">napoleon Boakye</a></span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">salma</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name"><a class="url" href="http://www.machinelearningmentor.com" rel="external nofollow ugc">napoleon Boakye</a></span>, <span class="name">Francesco D'Amore</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Jason Wills</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Jason Wills</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">maisie Badami</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Radya</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Radya</span>, <span class="name">neha rahman</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Abbey</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Sam Wilson</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Danie Truter</span>, <span class="name">Muhammad Faisal</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">priyanka yemul</span>, <span class="name"><a class="url" href="http://MachineLearningMastery.com" rel="external nofollow ugc">Jason Brownlee</a></span>, <span class="name">Chris Jarvis</span>, <span class="name"><a class=" ...

# %%
productloop=[product.text for product in products]
commentloop=[comment.text for comment in comments]

# %%
print(productloop)
# Out:
# ['Gibachan', 'Jason Brownlee', 'Priyankar', 'Jason Brownlee', 'Roman', 'sk', 'Jason Brownlee', 'Rita', 'Jason Brownlee', 'Tooba', 'Swapnil Pote', 'Ibrahim Amer', 'Dudley Jude', 'Jason Brownlee', 'Ali', 'Jason Brownlee', 'Mike Rauner', 'Jason Brownlee', 'Alan Beckles MD MS', 'Jason Brownlee', 'Alan Beckles MD MS', 'napoleon Boakye', 'Jason Brownlee', 'salma', 'Jason Brownlee', 'napoleon Boakye', "Francesco D'Amore", 'Jason Brownlee', 'Jason Wills', 'Jason Brownlee', 'Jason Wills', 'Jason Brownlee', 'maisie Badami', 'Jason Brownlee', 'Radya', 'Jason Brownlee', 'Radya', 'neha rahman', 'Jason Brownlee', 'Abbey', 'Jason Brownlee', 'Sam Wilson', 'Jason Brownlee', 'Danie Truter', 'Muhammad Faisal', 'Jason Brownlee', 'priyanka yemul', 'Jason Brownlee', 'Chris Jarvis', 'Jason Brownlee', 'Danie Truter', 'Jason Brownlee', 'Cyriac Peter', 'Jason Brownlee', 'Tran Anh Tuan', 'Jason Brownlee', 'Murali', 'Jason Brownlee', 'arif', 'Jason Brownlee', 'arif', 'Jason Brownlee', 'arif', 'Jason Brownlee', 'shivam tripathi', 'Jason Brownlee', 'Mani', 'Jason Brownlee', 'Tofa', 'Jason Brownlee', 'Anthony', 'Jason Brownlee', 'Dubem', 'Jason Brownlee', 'Neel', 'Jason Brownlee', 'Neel', 'Jason Brownlee', 'Yukin', 'Jason Brownlee', 'Suchithra', 'Jason Brownlee', 'mera', 'Jason Brownlee', 'jayaram', 'Jason Brownlee', 'Sudha', 'Jason Brownlee', 'mhamed kassem', 'Jason Brownlee', 'Cathy', 'Jason Brownlee', 'Sudha', 'Jason Brownlee', 'naivebae', 'Jason Brownlee', 'naivebae', 'Jason Brownlee', 'naivebae', 'Jason Brownlee', 'Sukesh Kumar Ranjan', 'Jason Brownlee', 'Souha', 'Jason Brownlee', 'chithambaram', 'Jason Brownlee', 'Javed Iqbal', 'Jason Brownlee', 'Hamed', 'Jason Brownlee', 'Hamed', 'Precious', 'Jason Brownlee', 'JD Maloy', 'Jason Brownlee', 'nazek hassouneh', 'Jason Brownlee', 'nazek hassouneh', 'Alexander', 'Jason Brownlee', 'Tyler', 'Jason Brownlee', 'Mat Rawsthorne', 'Jason Brownlee', 'Mat Rawsthorne', 'Jason Brownlee', 'Alaa', 'Jason Brownlee', 'Imtiyaz', 'Jason Brownlee', 'Kelemu', 'Jason Brownlee', 'anna', 'Jason Brownlee', 'hans', 'Jason Brownlee', 'Jomy', 'Jason Brownlee', 'Fabio', 'Jason Brownlee', 'AJITH L M', 'Jason Brownlee', 'Shreenivas Londhe', 'Jason Brownlee', 'Hazem', 'Jason Brownlee', 'Hazem', 'Jason Brownlee', 'Hazem', 'Jason Brownlee', 'ilham', 'Jason Brownlee', 'Rayan', 'Jason Brownlee', 'Deepansh Agrawal', 'Jason Brownlee', 'Amit', 'Jason Brownlee', 'Sama', 'Jason Brownlee', 'shano', 'Jason Brownlee', 'Sean King', 'Jason Brownlee', 'Karthik Mudlapur', 'Jason Brownlee', 'Preethi S', 'Jason Brownlee', 'Dr. Upasana Sharma', 'Jason Brownlee', 'Ankit Sethia', 'Jason Brownlee', 'Aarvish', 'Jason Brownlee', 'Kumar', 'Jason Brownlee', 'Jack Liu', 'Jason Brownlee', 'Md. Abbas Ali Khan', 'Jason Brownlee', 'Tingting', 'Jason Brownlee', 'Amit Jindia', 'Jason Brownlee', 'Izzy', 'Izzy', 'Jason Brownlee', 'Izzy', 'Jason Brownlee', 'Izzy', 'Jason Brownlee', 'Tejas B', 'Jason Brownlee', 'Nadjema bouaroui', 'Jason Brownlee', 'Mohanish', 'Jason Brownlee', 'shivan', 'Jason Brownlee', 'shivan', 'Jason Brownlee', 'Sami', 'Jason Brownlee', 'Andrews', 'Jason Brownlee', 'Osahon Okoro', 'Jason Brownlee', 'James Lee', 'Jason Brownlee', 'BHAVI', 'Jason Brownlee', 'BHAVI', 'Jason Brownlee', 'Harvey Jones', 'Jason Brownlee', 'Mik', 'Jason Brownlee', 'safeharbourship', 'Jason Brownlee', 'Temesgen', 'Jason Brownlee', 'Valarmathi Srinivasan', 'Jason Brownlee', 'Ezz', 'Jason Brownlee', 'Luciana Silva', 'Jason Brownlee', 'Andy', 'Jason Brownlee', 'Ravita Mishra', 'Jason Brownlee', 'saif hameed', 'Jason Brownlee', 'Prasannaa', 'Jason Brownlee', 'Monisha R', 'Jason Brownlee', 'ubie', 'Jason Brownlee', 'Twenty Oktavia', 'Jason Brownlee', 'JG', 'Jason Brownlee', 'Medium', 'Jason Brownlee', 'CArlos cuesta', 'Jason Brownlee', 'krishnapriya', 'Jason Brownlee', 'krishnapriya', 'Jason Brownlee', 'lakshmi', 'Jason Brownlee', 'Krishna Priya', 'Jason Brownlee', 'Rajesh SANYAL', 'Jason Brownlee', 'Renisha', 'Jason Brownlee', 'Adnan', 'Jason Brownlee', 'Saeid Rezaei', 'Jason Bro ...

# %%
print(commentloop)
# Out:
# ['\nIf the deep learning is such great algorithm, do you think that other older algorithms (like SVM) are no longer efficient to solve our problems?\n\nReply \n', '\nI think that SVM and similar techniques still have their place. It seems that the niche for deep learning techniques is when you are working with raw analog data, like audio and image data.\n\nReply \n', '\nCould you please give me some idea, how deep learning can be applied on social media data i.e. twitter.\n\nReply \n', '\nStart by defining your problem:\nhttp://machinelearningmastery.com/how-to-define-your-machine-learning-problem/\n\nReply \n', '\nMe too\n\nReply \n', '\ncan you tell what could be research for MS level in deep learning?\n\nReply \n', '\nThis is a common question that I answer here:\nhttps://machinelearningmastery.com/faq/single-faq/what-research-topic-should-i-work-on\n\nReply \n', '\nif I want to reconstruct 3D object, which is better, such as ANN, CNN, deep convolutional auto-encoder?\n\nReply \n', '\nPerhaps check the literature (scholar.google.comn) and discover what models are state of the art for your problem.\n\nReply \n', '\nfirst of all I would like to appreciate your effort. This is one of the best blog on deep learning I have read so far.\nWell I would like to ask you if we need to extract some data like advertising boards from image, what you suggest is better SVM or CNN or do you have any better algorithm than these two in your mind?\n\nReply \n', '\nCNN will give better result as compare to svm in image classification\n\nReply \n', '\nCNN would be extremely better than SVM if and only if you have enough data. The reason that CNN would be better is that CNN work as an automatic feature extractor and you won’t need to bother yourself of feature selection and wondering if the extracted feature would weather work with the model or not. CNN extracts all possible features, from low-level features like edges to higher-level features like faces and objects.\n\nReply \n', '\nAs an Adult Education instructor (Andragogy), how can I apply deep learning in the conventional classroom environment?\n\nReply \n', '\nPerhaps start by defining your problem clearly:\nhttp://machinelearningmastery.com/how-to-define-your-machine-learning-problem/\n\nReply \n', '\nPlz, anybody has Matlab code for CNN.\n\nReply \n', '\nMatlab is not so useful in production environments, it’s more used at school. It’s not really the focus of this site.\n\nReply \n', '\nTo answer your question, I would suggest you read this article – https://www.simplilearn.com/tutorials/deep-learning-tutorial/deep-learning-frameworks as it clearly explains the Deep Learning algorithms\n\nReply \n', '\nThanks for sharing.\nIt summarises deep learning libraries, not algorithms.\n\nReply \n', '\nCan CNNs perform tasks such as Medical Diagnosis or should they be  \ncombined with another technique such as Reinforement Learning to  \noptimize performance?\n\nReply \n', '\nGenerally, CNNs are really good at working with image data. \nMedical Diagnosis seems like a really broad domain. You may want to narrow your scope and clearly define and frame your problem before selecting specific algorithms.\n\nReply \n', '\nECG interpretation may be a good problem for CNNs in that they are images. Another project is the development of  a Consultant in Cardiovascular Disease analogous to MYCIN, an Infectious Disease Consultatant developed by Shortliffe & Buchanan @ Stanford ~ 40 years ago which was Rule Based.\n\nReply \n', '\nSo Jason, what is the next discovery after “deep learning”?\n\nReply \n', '\nNo idea Napoleon. Deep learning has enough potential to keep us busy for a long while.\n\nReply \n', '\nsir plz let me know on what basis cnn is extracting features from an image….\n\nReply \n', '\nWhat do you mean exactly?\n\nReply \n', '\nOkay\n\nReply \n', '\nGood overview.\nTake a look at this:\nhttp://deeplearning4j.org/\nIt could be a good tool for DL?\n\nReply \n', '\nThanks Francesco.\n\nReply \n',  ...

# %%
data={'Name':productloop, 'comments':commentloop}

# %%
data
# Out:
# {'Name': ['Gibachan',
#   'Jason Brownlee',
#   'Priyankar',
#   'Jason Brownlee',
#   'Roman',
#   'sk',
#   'Jason Brownlee',
#   'Rita',
#   'Jason Brownlee',
#   'Tooba',
#   'Swapnil Pote',
#   'Ibrahim Amer',
#   'Dudley Jude',
#   'Jason Brownlee',
#   'Ali',
#   'Jason Brownlee',
#   'Mike Rauner',
#   'Jason Brownlee',
#   'Alan Beckles MD MS',
#   'Jason Brownlee',
#   'Alan Beckles MD MS',
#   'napoleon Boakye',
#   'Jason Brownlee',
#   'salma',
#   'Jason Brownlee',
#   'napoleon Boakye',
#   "Francesco D'Amore",
#   'Jason Brownlee',
#   'Jason Wills',
#   'Jason Brownlee',
#   'Jason Wills',
#   'Jason Brownlee',
#   'maisie Badami',
#   'Jason Brownlee',
#   'Radya',
#   'Jason Brownlee',
#   'Radya',
#   'neha rahman',
#   'Jason Brownlee',
#   'Abbey',
#   'Jason Brownlee',
#   'Sam Wilson',
#   'Jason Brownlee',
#   'Danie Truter',
#   'Muhammad Faisal',
#   'Jason Brownlee',
#   'priyanka yemul',
#   'Jason Brownlee',
#   'Chris Jarvis',
#   'Jason Brownlee',
#   'Danie Truter',
#   'Jason Brownlee',
#   'Cyriac Peter',
#   'Jason Brownlee',
#   'Tran Anh Tuan',
#   'Jason Brownlee',
#   'Murali',
#   'Jason Brownlee',
#   'arif',
#   'Jason Brownlee',
#   'arif',
#   'Jason Brownlee',
#   'arif',
#   'Jason Brownlee',
#   'shivam tripathi',
#   'Jason Brownlee',
#   'Mani',
#   'Jason Brownlee',
#   'Tofa',
#   'Jason Brownlee',
#   'Anthony',
#   'Jason Brownlee',
#   'Dubem',
#   'Jason Brownlee',
#   'Neel',
#   'Jason Brownlee',
#   'Neel',
#   'Jason Brownlee',
#   'Yukin',
#   'Jason Brownlee',
#   'Suchithra',
#   'Jason Brownlee',
#   'mera',
#   'Jason Brownlee',
#   'jayaram',
#   'Jason Brownlee',
#   'Sudha',
#   'Jason Brownlee',
#   'mhamed kassem',
#   'Jason Brownlee',
#   'Cathy',
#   'Jason Brownlee',
#   'Sudha',
#   'Jason Brownlee',
#   'naivebae',
#   'Jason Brownlee',
#   'naivebae',
#   'Jason Brownlee',
#   'naivebae',
#   'Jason Brownlee',
#   'Sukesh Kumar Ranjan',
#   'Jason Brownlee',
#   'Souha',
#   'Jason Brownlee',
#   'chithambaram',
#   'Jason Brownlee',
#   'Javed Iqbal',
#   'Jason Brownlee',
#   'Hamed',
#   'Jason Brownlee',
#   'Hamed',
#   'Precious',
#   'Jason Brownlee',
#   'JD Maloy',
#   'Jason Brownlee',
#   'nazek hassouneh',
#   'Jason Brownlee',
#   'nazek hassouneh',
#   'Alexander',
#   'Jason Brownlee',
#   'Tyler',
#   'Jason Brownlee',
#   'Mat Rawsthorne',
#   'Jason Brownlee',
#   'Mat Rawsthorne',
#   'Jason Brownlee',
#   'Alaa',
#   'Jason Brownlee',
#   'Imtiyaz',
#   'Jason Brownlee',
#   'Kelemu',
#   'Jason Brownlee',
#   'anna',
#   'Jason Brownlee',
#   'hans',
#   'Jason Brownlee',
#   'Jomy',
#   'Jason Brownlee',
#   'Fabio',
#   'Jason Brownlee',
#   'AJITH L M',
#   'Jason Brownlee',
#   'Shreenivas Londhe',
#   'Jason Brownlee',
#   'Hazem',
#   'Jason Brownlee',
#   'Hazem',
#   'Jason Brownlee',
#   'Hazem',
#   'Jason Brownlee',
#   'ilham',
#   'Jason Brownlee',
#   'Rayan',
#   'Jason Brownlee',
#   'Deepansh Agrawal',
#   'Jason Brownlee',
#   'Amit',
#   'Jason Brownlee',
#   'Sama',
#   'Jason Brownlee',
#   'shano',
#   'Jason Brownlee',
#   'Sean King',
#   'Jason Brownlee',
#   'Karthik Mudlapur',
#   'Jason Brownlee',
#   'Preethi S',
#   'Jason Brownlee',
#   'Dr. Upasana Sharma',
#   'Jason Brownlee',
#   'Ankit Sethia',
#   'Jason Brownlee',
#   'Aarvish',
#   'Jason Brownlee',
#   'Kumar',
#   'Jason Brownlee',
#   'Jack Liu',
#   'Jason Brownlee',
#   'Md. Abbas Ali Khan',
#   'Jason Brownlee',
#   'Tingting',
#   'Jason Brownlee',
#   'Amit Jindia',
#   'Jason Brownlee',
#   'Izzy',
#   'Izzy',
#   'Jason Brownlee',
#   'Izzy',
#   'Jason Brownlee',
#   'Izzy',
#   'Jason Brownlee',
#   'Tejas B',
#   'Jason Brownlee',
#   'Nadjema bouaroui',
#   'Jason Brownlee',
#   'Mohanish',
#   'Jason Brownlee',
#   'shivan',
#   'Jason Brownlee',
#   'shivan',
#   'Jason Brownlee',
#   'Sami',
#   'Jason Brownlee',
#   'Andrews',
#   'Jason Brownlee',
#   'Osahon Okoro',
#   'Jason Brownlee',
#   'James Lee',
#   'Jason Brownlee',
#   'BHAVI',
#   'Jason Brownlee',
#   'BHAVI',
#   'Jason Brownlee',
#   'Harvey Jones',
#   'Jason Brownlee',
#   'Mik',
#   'Jason Brownlee',
#   'safeharbourship',
#   'Jason Brownlee',
#   'Temesgen',
#   'Jason Brownlee',
#   'Valarmathi Srinivasan',
#   'Jason Brownlee',
#   'Ezz',
#   'Jason Brownlee',
#   'Luciana Silva',
#   'Jason Brownlee',
#   'Andy',
#   'Jason Brownlee',
#   'Ravita Mishra',
#   'Jason Brownlee',
#   'saif hameed',
#   'Jason Brownlee',
#   'Prasannaa',
#   'Jason Brownlee',
#   'Monisha R',
#   'Jason Brownlee',
#   'ubie',
#   'Jason Brownlee',
#   'Twenty Oktavia',
#   'Jason Brownlee',
#   'JG',
#   'Jason Brownlee',
#   'Medium',
#   'Jason Brownlee',
#   'CArlos cuesta',
#   'Jason Brownlee',
#   'krishnapriya',
#   'Jason Brownlee',
#   'krishnapriya',
#   'Jason Brownlee',
#   'lakshmi',
#   'Jason Brownlee',
#   'Krishna Priya',
#   'Jason Brownlee',
#   'Rajesh SANYAL',
#   'Jason Brownlee',
#   'Renisha',
#   'Jason Brownlee',
#   'Adnan',
#   'Jason Brownlee',
#   'Saeid Rezaei',
#   'Jason Brownlee',
#   'Ahmed Hamed',
#   'Jason Brownlee',
#   'Ahmed Hamed',
#   'Roshan',
#   'Jason Brownlee',
#   'Shahbaz',
#   'Jason Brownlee',
#   'KULDEEP',
#   'Jason Brownlee',
#   'Mary Hill',
#   'Jason Brownlee',
#   'Alice',
#   'Jason Brownlee',
#   'Alice',
#   'Jason Brownlee',
#   'Kofi Antwi',
#   'Adrian Tam',
#   'Capital Time',
#   'Aakash',
#   'deepika',
#   'James Carmichael',
#   'Camila',
#   'James Carmichael',
#   'Fatima'],
#  'comments': ['\nIf the deep learning is such great algorithm, do you think that other older algorithms (like SVM) are no longer efficient to solve our problems?\n\nReply \n',
#   '\nI think that SVM and similar techniques still have their place. It seems that the niche for deep learning techniques is when you are working with raw analog data, like audio and image data.\n\nReply \n',
#   '\nCould you please give me some idea, how deep learning can be applied on social media data i.e. twitter.\n\nReply \n',
#   '\nStart by defining your problem:\nhttp://machinelearningmastery.com/how-to-define-your-machine-learning-problem/\n\nReply \n',
#   '\nMe too\n\nReply \n',
#   '\ncan you tell what could be research for MS level in deep learning?\n\nReply \n',
#   '\nThis is a common question that I answer here:\nhttps://machinelearningmastery.com/faq/single-faq/what-research-topic-should-i-work-on\n\nReply \n',
#   '\nif I want to reconstruct 3D object, which is better, such as ANN, CNN, deep convolutional auto-encoder?\n\nReply \n',
#   '\nPerhaps check the literature (scholar.google.comn) and discover what models are state of the art for your problem.\n\nReply \n',
#   '\nfirst of all I would like to appreciate your effort. This is one of the best blog on deep learning I have read so far.\nWell I would like to ask you if we need to extract some data like advertising boards from image, what you suggest is better SVM or CNN or do you have any better algorithm than these two in your mind?\n\nReply \n',
#   '\nCNN will give better result as compare to svm in image classification\n\nReply \n',
#   '\nCNN would be extremely better than SVM if and only if you have enough data. The reason that CNN would be better is that CNN work as an automatic feature extractor and you won’t need to bother yourself of feature selection and wondering if the extracted feature would weather work with the model or not. CNN extracts all possible features, from low-level features like edges to higher-level features like faces and objects.\n\nReply \n',
#   '\nAs an Adult Education instructor (Andragogy), how can I apply deep learning in the conventional classroom environment?\n\nReply \n',
#   '\nPerhaps start by defining your problem clearly:\nhttp://machinelearningmastery.com/how-to-define-your-machine-learning-problem/\n\nReply \n',
#   '\nPlz, anybody has Matlab code for CNN.\n\nReply \n',
#   '\nMatlab is not so useful in production environments, it’s more used at school. It’s not really the focus of this site.\n\nReply \n',
#   '\nTo answer your question, I would suggest you read this article – https://www.simplilearn.com/tutorials/deep-learning-tutorial/deep-learning-frameworks as it clearly explains the Deep Learning algorithms\n\nReply \n',
#   '\nThanks for sharing.\nIt summarises deep learning libraries, not algorithms.\n\nReply \n',
#   '\nCan CNNs perform tasks such as Medical Diagnosis or should they be  \ncombined with another technique such as Reinforement Learning to  \noptimize performance?\n\nReply \n',
#   '\nGenerally, CNNs are really good at working with image data. \nMedical Diagnosis seems like a really broad domain. You may want to narrow your scope and clearly define and frame your problem before selecting specific algorithms.\n\nReply \n',
#   '\nECG interpretation may be a good problem for CNNs in that they are images. Another project is the development of  a Consultant in Cardiovascular Disease analogous to MYCIN, an Infectious Disease Consultatant developed by Shortliffe & Buchanan @ Stanford ~ 40 years ago which was Rule Based.\n\nReply \n',
#   '\nSo Jason, what is the next discovery after “deep learning”?\n\nReply \n',
#   '\nNo idea Napoleon. Deep learning has enough potential to keep us busy for a long while.\n\nReply \n',
#   '\nsir plz let me know on what basis cnn is extracting features from an image….\n\nReply \n',
#   '\nWhat do you mean exactly?\n\nReply \n',
#   '\nOkay\n\nReply \n',
#   '\nGood overview.\nTake a look at this:\nhttp://deeplearning4j.org/\nIt could be a good tool for DL?\n\nReply \n',
#   '\nThanks Francesco.\n\nReply \n',
#   '\nhello, may deep learning apply to use in the stock market ?\nWhat I mean : it doesn’t just only use to draw with old data diagram and use the old model but also write down how is the next day to give the number forecast ?\n\nReply \n',
#   '\nHi Jason, deep learning may apply to the stock market. \nI am not an expert in finance so I cannot give you expert advice. Try it and see.\nYou may be interested in this post on time series forecasting with deep learning:\nhttp://machinelearningmastery.com/time-series-prediction-with-deep-learning-in-python-with-keras/\n\nReply \n',
#   '\nThank for your reply, I have read some your posts and I am very impressed with your work. About myself , I just start to find out what is this filed and you have many experiences about them. I hope if you have some experiences about the finance especially in stock market…pls help me some reference to learn it by myself or find the “Tribute”as you mentioned 🙂\n\nReply \n',
#   '\nThanks Jason, it’s great to have you here.\n\nReply \n',
#   '\nloved it , thanks for the overview , answered to a lot of my question  \nI am trying to find a topic for my Master-PHD proposal in Deep Learning in medical diagnosis and just wondering if there is any hot topic in this field at the moment ? and how can I learn more about this special field of Deep Learning\n\nReply \n',
#   '\nI’m glad to hear it was useful Maisie.\nI would suggest talking to medical diagnosis people about big open problems where there is access to lots of data.\n\nReply \n',
#   '\nHi maisie\nI am looking for some information for my master thesis either about CNN and deep learning in medical diagnosis\nSo plz if u find anything usefull help me cause I’m new in the feild\n\nReply \n',
#   '\nSounds like a great area.\nPerhaps start by reviewing recent papers on the topic?\n\nReply \n',
#   '\nI am already but it seem a bit hard\nI am looking for advices so I can continue\n\nReply \n',
#   '\ni am looking for M tech thesis in this topic…help me explore new areas….\n\nReply \n',
#   '\nHi neha, the best person to talk to about research topic ideas is your advisor. Best of luck.\n\nReply \n',
#   '\nHi Jason,\nThank you so much for your post. I am trying to solve an open problem with regards to embedded short text messages on the social media which are abbreviation, symbol and others. For instance, take bf can be interpret as boy friend or best friend. The input can be represent as  character but how can someone encode this as input in neural network, so it can learn and output the target at the same time. Please help.\nRegards\nAbbey\n\nReply \n',
#   '\nVery cool problem Abbey.\nI would suggest starting off by collecting a very high-quality dataset of messages and expected translation.\nI would then suggest encoding the words as integers and use a word embedding to project the integer vectors into a higher dimensional space.\nLet me know how you go.\n\nReply \n',
#   '\nHi, thanks for the good overview. \nIn your opinion, on what field CNN could be used in developing countries?\nBecause there seems less raw data than developed countries, i couldn’t think of any use of CNN in developing countries.\n\nReply \n',
#   '\nSorry Sam, I don’t know.\nCNNs are state of the art on many problems that have spatial structure (or structure that can be made spatial). \nAnything with images is a great start, domains like text and time series are also interesting.\n\nReply \n',
#   '\nHi… I am an average developer in a developing country and my opinion is “yes”… if you find a way to get all these “disconnected” data together than you can help on gathering these data to make it easier for developing countries not to make the same mistakes as developed countries… thus bringing the cost down on “becoming” a developed country without the cost… the “research” exist… the implementation is the problem…\n\nReply \n',
#   '\nHello Jason,\na very well and nicely explained article for the beginners.\nI would like to ask one question, Please tell me any specific example in the area of computer vision, where shallow learning (Conventional Machine Learning) is much better than Deep Learning.\n\nReply \n',
#   '\nGreat question, I’m not sure off hand. Computer Vision is not really my area of expertise.\n\nReply \n',
#   '\nThis article is useful for learning deep learning .Nice article\n\nReply \n',
#   '\nThanks priyanka.\n\nReply \n',
#   '\nWonderful summary of Deep Learning – I am doing an undergraduate dissertation/thesis on applying Artificial Intelligence to solving Engineering problems.\n\nReply \n',
#   '\nThanks Chris! Good luck with your thesis.\n\nReply \n',
#   '\nHi… I am just an average normal developer, but I find this article very informative… \nMay I please ask one question:\nIf the “internet” and “line speed” was fast enough, would it mean these algorithms could learn itself or are the “programs” currently limited to human interaction during the learning stage… \nSo my actual question: the “data” according to me is available -> “internet” BUT do we (humanity currently) already have the computational ability to make “sense” of the data via these algorithms AND are the software developed in such a way to ignore human approval?\n\nReply \n',
#   '\nThe data needed to learn for a given problem varies from problem to problem. As does the source of data and the transmission of data from the source to the learning algorithm.\n\nReply \n',
#   '\nDr Jason, this is an immensely helpful compilation. I researched quite a bit today to understand what Deep Learning actually is. I must say all articles were helpful, but yours make me feel satisfied about my research today. Thanks again. \nBased on my readings so far, I feel predictive analytics is at the core of both machine learning and deep learning is an approach for predictive analytics with accuracy that scales with more data and training. Would like to hear your thoughts on this.\n\nReply \n',
#   '\nThanks. I’m very glad to hear it.\nPredictive modeling is a sub-field of machine learning, and is by far the most useful area/the area of interest right now:\nhttp://machinelearningmastery.com/gentle-introduction-to-predictive-modeling/\n\nReply \n',
#   '\nThis article is very interesting and useful for a beginner in machine learning like me. \nI am thinking about a project (just for my hobby) of designing a stabilization controller for a DIY Quadrotor. Do you have any advice on how and where I should start off? Can algorithms like SVM be used in this specific purpose? Is micro controller (like Arduino) able to handle this problem? \nThank you in advance\n\nReply \n',
#   '\nSounds like a lot of fun.\nConsider this process to work through your problem:\nhttp://machinelearningmastery.com/start-here/#process\n\nReply \n',
#   '\nhi\nIs the Deep Learning is suitable for prediction of any diseases like Diabetes using data mining algorithms?\nIf yes give some ideas to work in it\n\nReply \n',
#   '\nIt may be good, but try a suite of algorithms to see what works best on your problem.\nSee this post:\nhttp://machinelearningmastery.com/a-data-driven-approach-to-machine-learning/\n\nReply \n',
#   '\nhi  jason are you fine i read  your article that help me  out and the comment section also\nmay i know that which is the latest algorithm in deep neural network \ni need your help about neural network . i am working on neural network thanks\n\nReply \n',
#   '\nThere are many deep learning algorithms. \nThe most popular are MLPs for tabular data, CNNs for image data and LSTMs for sequence data.\n\nReply \n',
#   '\nthanks jason in research base which algorithm you suggest for me to work\n\nReply \n',
#   '\nI would suggest you pick an area that most excites you.\n\nReply \n',
#   '\nJASON I WANT TO WORK IN MEDICAL AREA OR IMPLEMENT IN TO MEDICAL SITE\n\nReply \n',
#   '\nGreat! I wish you the best of luck.\n\nReply \n',
#   '\ndoes deep learning is a solution of over-fitting problem in machine learning?\n\nReply \n',
#   '\nNo, deep learning methods can overfit like any other.\n\nReply \n',
#   '\nThanks for the great article. What is the best approach for classifying products based on product description?\n\nReply \n',
#   '\nPerhaps use an LSTM or CNN or both combined.\n\nReply \n',
#   '\nLots of unnecessary points your explained which make difficult to understand what is actually deep learning is, also unnecessary explanaiton meke me bouring to read the document.\n\nReply \n',
#   '\nSorry to hear that.\n\nReply \n',
#   '\nJason,\nWhat do you think is the future of deep learning?\nHow many years do you think will it take before a new algorithm becomes popular?\n\nReply \n',
#   '\nHi Anthony,\nThere is not one algorithm, but a population with the headliners: MLP, LSTM and CNN.\nI do not know where we are headed, sorry.\n\nReply \n',
#   '\nI am a student of computer science and am to present a seminar on deep learning, I av no idea of what is all about…..can I get articles dat can aid Me\n\nReply \n',
#   '\nThis post would be a good start.\nI do not have much general material, but if you want to know how to use deep learning to solve problems, start here:\nhttp://machinelearningmastery.com/start-here/#deeplearning\n\nReply \n',
#   '\nHi Jason, I have been referring to a few of your blogs for my Machine Learning stuff. One striking feature of your blogs is simplicity which draws me regularly to this place! This is very helpful.:) Talking about Deep Learning vs traditional ML, the general conception is that Deep Learning beats a human being at its ability to do feature abstraction. Is this true?\nAlso, could you tell me why Deep Learning fails to achieve more than many of the traditional ML algorithms for different datasets despite the assumed superiority of DL in feature abstraction over other algorithms?\n\nReply \n',
#   '\nDeep learning is great at feature extraction and in turn state of the art prediction on what I call “analog data”, e.g. images, text, audio, etc.\nIt can be used on tabular data (e.g. spreadsheet of numbers) but this is not it’s sweet spot and often can be beaten by other methods, like gradient boosting.\nThere is no one algorithm to rule them all, just different algorithms for different problems and our job is to discover what works best on a given problem.\n\nReply \n',
#   '\nThanks for your response Jason! I appreciate your clarification.\n\nReply \n',
#   '\nYou’re welcome.\n\nReply \n',
#   '\nI am wondering that if I use a convolutional neural work in my train model, could I say it is deep learning?\n\nReply \n',
#   '\nYes.\n\nReply \n',
#   '\nSir , it’s a great review about deep learning\nMy question is what is the difference between deep neural network and CNN.\nIs deep learning is applicable to quantitative data( tabular data)\nI made a deep neural network model for bulk quantitative data and get a better result than traditional\u200b neural method.\nWhat it means sir ?\nIs my deep learning technique right?\n\nReply \n',
#   '\nA CNN is a type of neural network. It can be made deep. Therefore, it is a type of deep neural network.\nYes, neural nets require all input data to be tabular (vectorized).\nI cannot know if your model is right. Evaluate it carefully and compare it to other models.\n\nReply \n',
#   '\nif we use hierarchal training algorithm such as we use unsupervised learning autoencoder with bottleneck (hidden layer, 10,2,10) for training then use the supervised learning with same autoencoder architecture ( hidden layer, 10,2,10) to tune the unsupervised model parameter (weights, bias). These training processes are performed separately.\nnow the unsupervised autoencoder works as dimension reduction and extract features. does the supervised model work in the same way and extract the feature or just this step conducted in the unsupervised learning\n\nReply \n',
#   '\nhe supervised model will interpret the features and use them to make predictions.\n\nReply \n',
#   '\ncan i say deeplerning == cnn,  Do we  have types in deep learning\n\nReply \n',
#   '\nCNN is a type of deep learning. So is RNN and MLP.\n\nReply \n',
#   '\nSir, It is a good intro to deep learning. i’m planning to do phd in diagnosis of heart disease using deep learning. I have data’s of features. I don’t know how to classify those data. Can you please refer some material for numerical data classification using tensor flow.\n\nReply \n',
#   '\nI would recommend following this process when working through a new predictive modeling problem:\nhttps://machinelearningmastery.com/start-here/#process\n\nReply \n',
#   '\nhi , i have started in my graduation project , and i am creating a medical system based on data comes from medical sensors , and i hope to use deep learning in detecting the disease or the health case  based on  that data , but i don’t know from where i should start in deep learning\ncan you help me in doing it ?\n\nReply \n',
#   '\nMy best advice for getting started with deep learning in Python is here:\nhttps://machinelearningmastery.com/start-here/#deeplearning\n\nReply \n',
#   '\nHi Jason, thank you for the excellent overview. May I know how to apply deep learning in predicting adverse drug reactions, particularly in drug-drug interaction?\n\nReply \n',
#   '\nI recommend this process when starting on a new predictive modeling problem:\nhttps://machinelearningmastery.com/start-here/#process\n\nReply \n',
#   '\nHi Jason, Can you please tell me the unsupervised deep learning algorithms available? Please refer some link to learn about it.\n\nReply \n',
#   '\nSorry, I don’t have material on unsupervised learning algorithms, I don’t find them useful in practice.\n\nReply \n',
#   '\nWhat does “bigger models” mean? Are there more equations in the model? Are there more variables in the model? Are there more for loops? How exactly is the model “bigger”? What’s an example of a “not big model” and why is that worse? And what exactly is meant by the term “model” in this field? I’m still not clear on that. Like what exactly are the characteristics that make something a “model” and why is another general programming algorithm like, say, a loop that divides numbers successively to determine if an integer is prime, not a “model”? To me that sounds like a “model” for determining if a number is prime, so what is meant in this field by “model”? What are the inherent properties that make something a “model”? Is a model a type of algorithm? Is it a class in object-oriented design? What’s a “model” and what;s a “bigger model”?\n\nReply \n',
#   '\nToo many questions for one comment, sorry.\n\nReply \n',
#   '\nOk, let’s start by what exactly is meant by the term “model” in this field? Because I’m still absolutely not clear on what that means. If I write up some code to solve a problem, how do I know whether or not I’ve “built a model”?\n\nReply \n',
#   '\nA model is often referred to as the weights + structure after the training algorithm has been run on data.\nIt is the “program” that can make predictions on new data.\n\nReply \n',
#   '\nAnd then what’s the “bigger model” you refer to in this article? Are there more weights and more structure in the training algorithm? How is that achieved? Do you plug in more equations and more variables and decision parameters/whatever? How do you know what additional equations and parameters to plug in, and how do you know those are the right ones as opposed to others? Or does “bigger models” simply refer to running on more overall data, and the training algorithm is the same with the same amount of equations/variables/computations per training example?\n\n\n',
#   '\n“Larger Models” refers to deeper (more layers) or wider (more neurons per layer), ultimately more representational capacity.\n\n\n',
#   '\nBest summary for  students to learn basics of Deep Learning. Thank you Jason\n\nReply \n',
#   '\nThanks.\n\nReply \n',
#   '\nThank you very much.  It is very good summary about deep learning.\nCould you give some algorithms used in deep learning , please.\n\nReply \n',
#   '\nThe three to focus on are: Multilayer Perceptron, Convolutional Neural Network and Long Short-Term Memory Network.\n\nReply \n',
#   '\nhow deep learning can be applied in music ? is it possible to analyze existing music to compose new music by computers ?? If yes what type of algorithm should be used ?\n\nReply \n',
#   '\nYes, you could classify music or generate music.\n\nReply \n',
#   '\nDear Dr Jason Brownlee, I really found this very useful and helpful for beginners to this domain.\n\nReply \n',
#   '\nThanks.\n\nReply \n',
#   '\nI am familiar with machine learning and neural networks. My expertise is optimization and I am just interested in this field. What do you suggest as a good starting point? I prefer to learn it through experience and see how it works on different cases.\n\nReply \n',
#   '\nI have some advice for getting started here that might help:\nhttps://machinelearningmastery.com/start-here/#deeplearning\n\nReply \n',
#   '\nThanx a lot 🙂\n\nReply \n',
#   '\nWhat are the objective study of deep learning\n\nReply \n',
#   '\nSome are interested in the limits of the method and pushing those limits, e.g. academics.\nSome are interested in better solutions to hard problem, e.g. engineers.\nI focus on the latter here.\n\n\n',
#   '\nDo you think a deep-learning system could be “taught to read” in a manner similar to a young child?  That is:\n1. Visual input of the words on each page\n2. Coordinated (i.e. synchronized) sound input of those words being read\n3. Repeat/reinforce as needed by “reading” the same book multiple times\n4. Expand the data set by “reading” a variety of books\n…with the ultimate goal & test being to present the system with a book it hasn’t “seen” before, and have it “read” that book via a synthesized voice.\n(Never mind the robotics to turn the pages, we can leave that part to a human assist.)\n\nReply \n',
#   '\nA general system of this form could be constructed, not sure about the “like a child” part though.\n\nReply \n',
#   '\ni am nazek hassouneh\ni am a master student and my thesis in deep learning\ni have data set with class label\ni will use deep learning for classification\ndata set is an excel format and will convert to CSV form\ndata set with 49 attribute and 131,000 records\nhow can i use deep learning i need tutorial for that\ni need specific nueral networks  suitable for this data set\n\nReply \n',
#   '\nPerhaps this tutorial will help you get started:\nhttps://machinelearningmastery.com/tutorial-first-neural-network-python-keras/\n\nReply \n',
#   '\nthank you very much\n\nReply \n',
#   '\nVery Usefull Article In Deep Learning\n\nReply \n',
#   '\nThanks Alexander.\n\nReply \n',
#   '\nThanks Jason. Great article as always.\n\nReply \n',
#   '\nGlad to hear that.\n\nReply \n',
#   '\nHi Jason\nloving your articles on ML and NLP! Apologies if this is a daft question but do the extra layers in deep learning models make them more or less transparent? I am thinking in the context of looking for patterns of helpful comments in forum exchanges – would I be able to recognise the features discovered (e.g. as a series of IFTTT rules) or would they just come out as a series of factor weights?\nVery new to this so any pointers most welcome\nKeep up the good work\nbest wishes\nMat\n\nReply \n',
#   '\nLayers add layers of abstraction which makes the model more complex/opaque.\n\nReply \n',
#   '\nThanks Jason. I see that people have been making progress on increasing transparency in deep learning https://arxiv.org/abs/1710.09511\nI am working my way through your NLP crash course to understand more\n\nReply \n',
#   '\nThanks for the link.\n\nReply \n',
#   '\nHi ..\nIt’s a great blog I’ve ever seen , thanks a lot for all your efforts,  wish you the best 😊\nI am a master student and my thesis is about  breast cancer diagnosis , I want to know  is deep learning algorithm appropriate for my thesis\nand if the answer is yes which one is the best\nI’m so confused  plz help me 😢\n\nReply \n',
#   '\nI would recommend starting with CNNs for image data.\n\nReply \n',
#   '\nVery nice one.I want to use deep learning in tourism sector. I can manage to get the tourists data.\nCan you tell me how can i use deep learning in tourism sector.\nThanks\n\nReply \n',
#   '\nPerhaps start by framing your predictive modeling problem:\nhttp://machinelearningmastery.com/how-to-define-your-machine-learning-problem/\n\nReply \n',
#   '\nThanks for sharing these types of soul idea especially for like underresourced country. I am trying to do my thesis by “Object detection by Deep learning for autonomous Vehicle” which method prefer for accomplished my thesis.\n\nReply \n',
#   '\nGood luck with your project!\n\nReply \n',
#   '\na very useful for beginner like me. and right now i’m in doing research with title “analysis on deep learning method for heart disease. which suitable technique i should use ?\n\nReply \n',
#   '\nThanks.\nPerhaps try a suite of methods and see what works best for your specific dataset.\n\nReply \n',
#   '\nthanks very much jason for your valuable information , i have question about features extraction ;\ni know features selection , but what means by features extraction which is a property of deep Learning.\n\nReply \n',
#   '\nIt refers to methods that create features from analog data like images, audio and text:\nhttps://en.wikipedia.org/wiki/Feature_extraction\nThere is a lot of overlap with feature engineering.\n\nReply \n',
#   '\nWant to learn more about deep neural network and its variants. Could you please tell me how?\n\nReply \n',
#   '\nYes, start here:\nhttps://machinelearningmastery.com/start-here/#deeplearning\n\nReply \n',
#   '\nHello Jason,\nI’m a PhD student working on a decentralized IDS (Intrusion Detection System) platform utilizing Big Data, and I’m using machine learning algorithms to detect some signature based attacks.\nI’m researching if deep learning would be a good AI method to detect non-signature based attacks (anomalies). I’ve used neural networks to train a specific node to detect a specific signature based attack, but I’m new to deep learning and not sure how apply it into my model.\nWould Multilayer Perceptron, Convolutional Neural Network or Long Short-Term Memory Network algorithms applicable at detecting anomalies with gigantic amounts of raw data?\nThanks in advance and great article, very useful.\n\nReply \n',
#   '\nI would recommend testing a suite of methods to see what works best for your specific dataset.\n\nReply \n',
#   '\nIf i am new to this where can i start , eventhough i read the full article its difficult for me to get some technical terms ? So where can i start if i am starting from scratch?\nTHANK YOU\n\nReply \n',
#   '\nYou can start here:\nhttps://machinelearningmastery.com/start-here/#deeplearning\n\nReply \n',
#   '\nWhat about using Deep Learning in regression problems? Can it be useful for problems like ocean wave forecasting in univariate mode?\n\nReply \n',
#   '\nIt may be. Perhaps try it and see how you go.\n\nReply \n',
#   '\nthank you Doctor Jason Brownlee\n\xa0For the great effort you make\nI have several questions and I hope to be as broad as we used to\nCNN is one of the neural networks that can be very deep but my question here is the code that distinguishes between being a normal neural network and being a deep neural network knowing that it can be used in both cases\nI have implemented a deep learning application that predicts the status of my client as he will continue his service or not \nThe Code \nimport theano\nimport theano\nimport tensorflow\n# Importing the libraries\n    import numpy as np\n    import matplotlib.pyplot as plt\n    import pandas as pd\n# Importing the dataset\n    dataset = pd.read_csv(‘C:/Python34/Churn_Modelling.csv’)\nX = dataset.iloc[:, 3:13].values\ny = dataset.iloc[:, 13].values\nfrom sklearn.preprocessing import LabelEncoder, OneHotEncoder\nlabelencoder_X_1 = LabelEncoder()\nX[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])\nlabelencoder_X_2 = LabelEncoder()\nX[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])\nonehotencoder = OneHotEncoder(categorical_features = [1])\nX = onehotencoder.fit_transform(X).toarray()\nX = X[:, 1:]\n# Splitting the dataset into the Training set and Test set\nfrom sklearn.model_selection import train_test_split\nX_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4)\n# Feature Scaling\nfrom sklearn.preprocessing import StandardScaler\nsc = StandardScaler()\nX_train = sc.fit_transform(X_train)\nX_test = sc.transform(X_test)\n# Importing the Keras libraries and packages\nimport keras\nfrom keras.models import Sequential\nfrom keras.layers import Dense\n#Initializing Neural Network\nclassifier = Sequential()\n# Adding the input layer and the first hidden layer\nclassifier.add(Dense(activation=”relu”, kernel_initializer=”uniform”, units=7, input_dim=11))\n# Adding the second hidden layer\nclassifier.add(Dense(activation=”relu”, kernel_initializer=”uniform”, units=7))\n# Adding the output layer\nclassifier.add(Dense(activation=”sigmoid”, kernel_initializer=”uniform”, units=1))\n# Compiling Neural Network\nclassifier.compile(optimizer = ‘adam’, loss = ‘binary_crossentropy’, metrics = [‘accuracy’])\n# Fitting our model\nclassifier.fit(X_train, y_train, batch_size = 50, nb_epoch = 500)\n# Predicting the Test set results\ny_pred = classifier.predict(X_test)\ny_pred = (y_pred > 0.5)\n# Creating the Confusion Matrix\nfrom sklearn.metrics import confusion_matrix\ncm = confusion_matrix(y_test, y_pred)\nThe Data set \nThis application was found on the internet and its code is (Can I specify what functions (code) that make it a deep learning)\nAnd you have implemented an application for you to learn about God called Your First Machine Learning Project in Python\nWhat functions are used make me know whether this code is deep learning or machine learning\n \xa0In the past it was possible to put a lot of layers and use a large data size in MLP\nMLB is now one of the deep learning algorithms\n\xa0What code you have completed makes it a profound learning\nSorry for the delay I would like to explain to me the application has been applied using the deep learning algorithm which is the same algorithm application is not using deep learning\n\nReply \n',
#   '\nYou can define deep.\nLearn more here:\nhttps://machinelearningmastery.com/what-is-deep-learning/\n\nReply \n',
#   '\nI’m sorry to urge you Dr. Jason\nI would also like a small code showing the use of deep learning about traditional learning\n\nReply \n',
#   '\nWhat is “traditional learning” in the context of deep learning?\n\nReply \n',
#   '\nI mean traditional learning is the algorithms in which we do not use depth but similar in use\nLike RNN was used by the production of deep learning idea\nBut I mean what the code will differentiate between RNN and DNN, knowing that RNN and many of the previous algorithms are deep learning algorithms\nThank you for your patience with me\n\nReply \n',
#   '\nGenerally, any neural network may be referred to as deep learning now. I don’t see a practical distinction other than for marketing.\n\nReply \n',
#   '\nDear Mr. Jason, there is one thing I don’t understand. In the article it is said that Deep Learning’s performance get better with more data while other, older algorithms tends to reach a plateau. Can you explain more and give an example about the plateau?\nInitially I think the plateau is there because more data can cause overfitting, but after some browsing I found out that more data will decrease the chance of overfitting. It is the number of feature, not the number of data that causes overfitting. The only thing I can think about how more data can create plateau is on heuristic algorithm, which can create more local minima where algorithms can get stuck on.\n\nReply \n',
#   '\nSorry, I do not have a direct reference.\n\nReply \n',
#   '\nThanks John. I found the article very useful.\nI am now confident I know what deep learning is.\n\nReply \n',
#   '\nGlad to hear it.\n\nReply \n',
#   '\nA very good blog John. I am a newbie to the field of Deep Learning and this blog has helped me well.\nThanks\n\nReply \n',
#   '\nI’m glad it helped, also, my name is “Jason”.\n\nReply \n',
#   '\nCan we detect Malware Infections/DOS/Brute Force Attacks on any Network using Deep Learning?\n\nReply \n',
#   '\nProbably.\n\nReply \n',
#   '\nHi, I want to know what are the deep learning methods using PAC Bayesian. And then compare them with other kind of methods.\nwould you please clarify for me this problem?\n\nReply \n',
#   '\nSorry, I don’t have material on this topic.\n\nReply \n',
#   '\nhttps://www.technoonews.com/2018/08/what-is-neural-network.html\ntechnology lover\n\nReply \n',
#   '\nThanks for sharing.\n\nReply \n',
#   '\nMy brain just imploded.\n\nReply \n',
#   '\nSorry to hear that Sean.\n\nReply \n',
#   '\nAmazing read and this article has given me a head start to write my Master thesis in this field. Thanks.\n\nReply \n',
#   '\nI’m glad to hear that.\n\nReply \n',
#   '\nHai Sir,\nI am Preethi, working with Visual Studio C++. My research problem is related to classification and prediction. Now I am trying to use the deep concept (sparse autoencoder ) in my problem, but I didnt get any C++ package for autoencoder. I found so many python packages, but I have to follow VS C++. OpenCV offers modules for CNN ,not for autoencoders.\nCould you pl suggest me any package to use with VS C++?\nWaiting for your kind response.\n\nReply \n',
#   '\nSorry, I’m not familiar with cpp libraries for deep learning.\n\nReply \n',
#   '\nVery useful article on Deep Learning\n\nReply \n',
#   '\nThanks.\n\nReply \n',
#   '\nKindly explain Convolutional Nets Model of Deep Learning in detail.\n\nReply \n',
#   '\nSure:\nhttp://machinelearningmastery.com/crash-course-convolutional-neural-networks/\n\nReply \n',
#   '\nDoes Particle Swarm Optimization and ant bee colony algorithms which comes under artificial intelligence is related to deep learning method or unsupervised learning techniques in machine learning\n\nReply \n',
#   '\nNot really, they are optimization algorithms.\nNeural networks are function approximation algorithms.\n\nReply \n',
#   '\nThis article has given me great knowledge on deep learning. currently doing research on data mining. Could you please suggest me how to apply deep learning for cancer classification. Right now I am applying cuckoo search optimization algorithm.\n\nReply \n',
#   '\nPerhaps try this process:\nhttps://machinelearningmastery.com/start-here/#process\n\nReply \n',
#   '\nHey I’m wondering what are your thoughts about AI being implemented into healthcare\n\nReply \n',
#   '\nSounds great!\n\nReply \n',
#   '\nHI,\nI am beginner and I want to make a CVML- Computer Vision and Machine Learning lab. What tools and requirement have I need.\n\nReply \n',
#   '\nSorry, I don’t know about setting up a lab.\n\nReply \n',
#   '\nThanks Jason. This article is so well written and informative.\n\nReply \n',
#   '\nThanks.\n\nReply \n',
#   '\nThanks. This article is so  informative.\n\nReply \n',
#   '\nI’m glad it helped.\n\nReply \n',
#   '\nHi Jason and thank you for such an enlightening article.\nWhat I understood is that the hidden layers act as feature learners from the data. They achieve\nthis by successively applying nonlinear transformations (with the activation functions) on the input data to map them into a new space: the feature space.\nIn case of a classification task, the classes become easier (linearly) to separatein this feature space.\nWhat about in the case of regression? What is the function of the hidden layers in a deep neural network model for regression. \nThank you in advance!\n\nReply \n',
#   '\nI would say: In case of regression, there is the nonlinear transformation of the input data to the feature space and there a linear regression in that new feature space can be applied to aproximate the numerical target variable.\n\nReply \n',
#   '\nNot quite, the model can learn a non-linear separation of classes.\nSame idea, but it learns a non-linear fit for association between the inputs to the output value.\n\nReply \n',
#   '\nok, thank you for the response.\nIs what I said  the case for SVR?\n\nReply \n',
#   '\nNot quite, an SVM can have a non-linear kernel.\n\nReply \n',
#   '\nyes sure. It is the non linear kernel that enables the non linear transformation of the input data to the feature space.\nIsn’t the same principle as the activation functions in the hidden layers of a deep neural network?\n\nReply \n',
#   '\nYes, similar.\n\nReply \n',
#   '\nHello Jeson\nthis is regarding deep learning mini cource. i have done some research and read some material about deep learning and for deep learning mini cource – lession 1 – task , below are the details as requested\n10 impressive applications of deep learning methods in the field of natural language processing\n1. Text summarization \nhttps://arxiv.org/pdf/1707.02268.pdf\n2. Robust real-time detection, tracking, and pose estimation of faces in video streams\nhttps://ieeexplore.ieee.org/abstract/document/1334689 \n3. Deep Residual Learning for Image Recognition\nhttp://openaccess.thecvf.com/content_cvpr_2016/html/He_Deep_Residual_Learning_CVPR_2016_paper.html\n 4. Multi-digit Number Recognition from Street View Imagery\nhttps://arxiv.org/abs/1312.6082\n5. Automatic whale counting in satellite images with deep learning\nhttps://www.biorxiv.org/content/10.1101/443671v1.abstract\n6. A short-term building cooling load prediction method using deep learning algorithms\nhttps://www.sciencedirect.com/science/article/pii/S0306261917302921\n7. Deep learning for pixel-level image fusion: Recent advances and future prospects\nhttps://www.sciencedirect.com/science/article/pii/S1566253517305936\n8. Reading Text in the Wild\nhttps://link.springer.com/article/10.1007/s11263-015-0823-z\n9. Neural Machine Translation by Jointly Learning to Align and Translate\nhttps://arxiv.org/abs/1409.0473 \n10. Interleaved Text/Image Deep Mining on a Large-Scale Radiology Database for Automated Image Interpretation\nhttp://www.jmlr.org/papers/volume17/15-176/15-176.pdf\ngoing through 2nd lession . Thank you for availing this information.\nHighly appreciated !!\nThanks\n\nReply \n',
#   '\nVery nice!\n\nReply \n',
#   '\nHi\nCan you help me for my  mastery\nStudy thé properties of deep learning approximation\n\nReply \n',
#   '\nYes, you can get started here:\nhttps://machinelearningmastery.com/start-here/#deeplearning\n\nReply \n',
#   '\nHi sir ,I have one question that how to train the cifar 10 dataset with opencv and python  such that after training it will generate xml file.\n     My aim is to ” Detect objects using OpenCV an python ”.\nAs I am new in this field, so please consider me.\n\nReply \n',
#   '\nSorry, I don’t have any tutorials on this topic, I may cover it in the future.\n\nReply \n',
#   '\nhello dear\nhow can I start with (Deep learning in medical image analysis) for my thesis \nthanks\n\nReply \n',
#   '\nPerhaps start here:\nhttps://machinelearningmastery.com/start-here/#dlfcv\n\nReply \n',
#   '\ngenerally, I should start with computer vision after that and the more specific subject is in medical image analysis, is it right …..thanks\n\nReply \n',
#   '\nI recommend that you start working on your project directly, rather than study subjects to get ready to work on your project.\nPerhaps the most appropriate methods will be deep learning models like pre-trained convolutional neural networks.\n\nReply \n',
#   '\nHello Everyone my thesis topic is “CLEFT FACIAL AESTHETIC OUTCOME EVALUATION BASED ON DEEP TRANSFER LEARNING” how can I use deep learning and transfer learning model and to combine them and develop cleft facial aesthetic outcome measure system please help me I am really worried about it\n\nReply \n',
#   '\nPerhaps start with a strong definition of the problem you’re solving.\nThis framework will help:\nhttp://machinelearningmastery.com/how-to-define-your-machine-learning-problem/\n\nReply \n',
#   '\nThanks for the information, now I understand\n\nReply \n',
#   '\nYou’re welcome.\n\nReply \n',
#   '\nThanks Jason.\nThe post really brought me to light about Deep learning. I don’t know if you can be of help for my M.Sc thesis. I intend to use deep learning to obtain sistolic and diastolic data readings from a wearable device then run it through CNN to produce a more accurate value as its output.\nThe CNN will run on a parallel architecture to accommodate the processing power. \nAnd being a consultant for an ICT firm, i will also want to know if you are open to take up some consultancy contract with the firm? You can reach me on my email: if you are interested.\n\nReply \n',
#   '\nThanks for asking, I no longer take consulting projects:\nhttps://machinelearningmastery.com/faq/single-faq/can-you-do-some-consulting\nYou will find these tutorials very helpful:\nhttps://machinelearningmastery.com/start-here/#deep_learning_time_series\n\nReply \n',
#   '\nBeen reading up a lot on machine learning/deep learning, AI thinking how I can use them to UP my marketing ANTE.  Will probably need a tech guy to really do it, but just wanted to get a good grasp about the topic and then I came across yours. Great article!\n\nReply \n',
#   '\nThanks James.\n\nReply \n',
#   '\nHi James ..your articles are always helping. can you please tell me ..how we can train a DQN model with the help of given dataset\n\nReply \n',
#   '\nI hope to cover that topic in the future.\n\nReply \n',
#   '\nI am waiting for your tutorial …….as they are the BEST\n\nReply \n',
#   '\nThanks.\n\nReply \n',
#   '\nThanks for the article. I read a few more articles and decided to work in Tensorflow for deep learning.\n\nReply \n',
#   '\nSounds great Harvey!\n\nReply \n',
#   '\nHi jason\nWhich part of deep learning needs to cogitated to improve deep learning?\nIs it approch of weigh choosing or the structure of neurals (number of layers and number of neuron in each layers or relation between each other)…. ?\nWhich part it is????\n\nReply \n',
#   '\nGreat question. Learning rate for sure.\nI outline more methods and a framework here:\nhttps://machinelearningmastery.com/start-here/#better\n\nReply \n',
#   '\ndeep learning in itself is an intense topic the way you have elaborate it is great job.please keep sharing such topic.\n\nReply \n',
#   '\nThanks.\n\nReply \n',
#   '\nhow can I start with (Deep learning in bitcoin price prediction) for my thesis\n\nReply \n',
#   '\nThis sounds like a time series problem.\nPerhaps start here:\nhttps://machinelearningmastery.com/start-here/#deep_learning_time_series\n\nReply \n',
#   '\nHello sir, \nWould like to know that how features are extracted in CNN\n\nReply \n',
#   '\nGreat question, I give an example here:\nhttps://machinelearningmastery.com/convolutional-layers-for-deep-learning-neural-networks/\n\nReply \n',
#   '\nHi. Being new to ML, this site is looking promising.Thank you.\nI was considering using Google AutoML (https://cloud.google.com/automl-tables/docs/ ) on structured and labelled (probabaly JSON) but very large sets of textual data, to encode some near-subjective decision making that could possibly be explicitly coded, but with quite some complexity.\nIt could just be more elegant and scalable if a machine model could be trained, with human guidance.\nIf that sounds at all feasible, should I start with machine-learning-in-r-step-by-step and at least get used to the field using the “shallow” ML algorithms mentioned there, or would deep-learning likely prove more beneficial but still be an intelligible subject to a newcomer?\nEventually I’d want to employ this in an app.\n\nReply \n',
#   '\nI think it is a good idea to get familiar with the basics of working through small problems end to end first.\nIt is the process I teach here:\nhttps://machinelearningmastery.com/start-here/#getstarted\n\nReply \n',
#   '\nHi. Your posts are really good. I am learning a lot about ML. I would like to know whether deep learning can tacke classification problems when I have an unlabeled or partially labeled dataset.\n\nReply \n',
#   '\nThanks!\nYes, this sounds like semi-supervised learning. \nI recommend testing a range of methods on your problem in order to discover what works best, including deep learning techniques.\n\nReply \n',
#   '\nJason,\nI am a CS student and have taken other classes in DL, yet the current material in an in-depth class has me challenged. I understand the concepts, but have a hard time completing working code with all the pieces in the time I am given.\nWe just finished RNN & CNN and for the next month will do reinforcement and unsupervised. I will be asked to take a network with distinct architecture and successfully train & test, most times with imported data. I am able to run different pieces of the code, but perfectly setting up all the parameters gives me a lot of trouble. \ndo you think your new book will help me?\n\nReply \n',
#   '\nSetting the right parameters gives everyone trouble.\nThe reason is there are no good theories for how to do it – the best we have is careful experimentation which basically means trial and error.\nMy books are not a magic bullet, it sounds like you’re getting good guidance from your course already.\nIf you need more advice on how to configure neural nets and diagnose faults, the tutorials here will help:\nhttps://machinelearningmastery.com/start-here/#better\n\nReply \n',
#   '\nHi Jason, I am Ravita Research scholar and doing research on scalable and efficient Job Recommendation using deep learning technique.\nI am new in deep learning technique, which algorithm is suitable for job recommendation.i am using CareerBuilder dataset. Pls. suggest me which algorithm give better accuracy and scalabilty.\n\nReply \n',
#   '\nGood question, perhaps this will help:\nhttps://machinelearningmastery.com/when-to-use-mlp-cnn-and-rnn-neural-networks/\n\nReply \n',
#   '\ni loved the text\nmy question is\nim going to work my PHD continue other relative work\nhe work on automatic image annotation he used CNN\ncon i continue using hybrid net. like CNN+LSTM+MLP or CNN+RNN something like that ?\n\nReply \n',
#   '\nPerhaps.\n\nReply \n',
#   '\nHow would you implement Predective mechanism for IT Service Management -Problems using Deep Learning\n\nReply \n',
#   '\nI would recommend testing a suite of algorithms for a problem and discover what works best, rather than starting with the solution (deep learning).\n\nReply \n',
#   '\nwhat are the reason(s) for the recent takeoff of deep learning?\n\nReply \n',
#   '\nIt works really well on very hard problems.\n\nReply \n',
#   '\nI want to create a speech to text using ANN-based cuckoo search optimisation. Can you guide me through\n\nReply \n',
#   '\nI don’t have tutorials on this topic, sorry.\n\nReply \n',
#   '\nTalking about deep learning, Airlangga University conducted a study of the Multi Projection Deep Learning Network for Segmentation in 3D Medical Radiographic Images. Want to know more? Visit the following link:\nhttp://news.unair.ac.id/2019/12/19/multi-projection-deep-learning-network-untuk-segmentasi-pada-gambar-radiografi-medis-3d/\nThank You\n\nReply \n',
#   '\nThanks for sharing.\n\nReply \n',
#   '\nGreat historical review and research about the persons and conceptual ideas behind the main milestones of Deep Learning development with keys references.\n I can see your are not only a great ML/DL populariser,  but also and not less, a great scientific researcher of ML/DL \nThanks Jason\n\nReply \n',
#   '\nThanks.\n\nReply \n',
#   '\nI did a quick skim over the information and plan on going back and rereading it. I was curious I have experience in HTML, CSS, Javascript, PHP, and C++. I am planning to also learn Binary, Python, and Assembly as well as a few others. The reason why is I want to build A.I. that cross the border of weak and strong A.I. and approaches the threshold of Super A.I.s. In order to do so I plan on creating a computer language but want a bunch of references to do so. So, in the end, my question is. What language do you recommend for Deep Learning and other coding languages?\n\nReply \n',
#   '\nPython:\nhttps://machinelearningmastery.com/faq/single-faq/what-programming-language-should-i-use-for-machine-learning\n\nReply \n',
#   '\nBuen artículo, he tenido que leerlo dos veces.\n\nReply \n',
#   '\nThanks!\n\nReply \n',
#   '\nsir, I want to do research in machine learning for predicting disease. I saw a lot of papers about that. most of the papers using small data sets. \nI want to increase the size of the data sets what is the best method for large data sets. is it possible with  MACHINE LEARNING? or deep learning is easy for large data sets\n\nReply \n',
#   '\nYes, see this:\nhttps://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/\n\nReply \n',
#   '\nit is not about an imbalanced dataset. if we are using thousands or lakhs of datasets are \nusing instead of hundreds of datasets.\n\nReply \n',
#   '\nThe best method for large datasets is the method that performs the best on your dataset, and meets the requirements of your project.\n\nReply \n',
#   '\nIs deep learning is used instead of using machine learning for predicting heart disease. for bigger data sets\n\nReply \n',
#   '\nDeep learning is a type of machine learning.\nYou must discover what works best for your dataset.\n\nReply \n',
#   '\nSir not about imbalanced data sets. In case if we are using thousands or lakhs of records are using instead of hundreds of recods.\n\nReply \n',
#   '\nThe best method for large datasets is the method that performs the best on your dataset, and meets the requirements of your project.\n\nReply \n',
#   '\nI am a Physics student….I have no basics for any computer language… But would like to learn about DL and ML …. Where should I start\n\nReply \n',
#   '\nYou may need to learn some Python first:\nhttps://machinelearningmastery.com/faq/single-faq/how-do-i-get-started-with-python-programming\nThen start here:\nhttps://machinelearningmastery.com/start-here/#deeplearning\n\nReply \n',
#   '\nHello sir, Can you provide an example for using deep learning to classify data that is in the form of CSV files?\n\nReply \n',
#   '\nYes, there are many on the blog, perhaps start here:\nhttps://machinelearningmastery.com/tutorial-first-neural-network-python-keras/\n\nReply \n',
#   '\nhi sir : i need to build a project for detected baby crying … so i need a model for sound of crying baby in AI algorithm can you help me plz ..\n\nReply \n',
#   '\nSorry, I don’t have tutorials on working with audio data. I cannot give you good off the cuff advice.\n\nReply \n',
#   '\nHello Jason, Thank you for your amazing blog. I have chosen the Deep Learning course this semester while I have a little information about Machine Learning, (I plan to choose ML course next semester). I wanna know is ML a prerequisite for deep learning? or I can learn Deep Learning algorithms and models and learn other classical ML algorithms simultaneously? Thank you in advance for your answer\n\nReply \n',
#   '\nI think you can learn both at the same time.\n\nReply \n',
#   '\nHello Jason,\nCan i use deep learning algorithm (CNN) in the resolution of optimization problem, example: I have a matrix with n*m values, in my case I need to select value from this matrix and turn the other to “0” in order to minimize the error or maximize energy?, Is there any matlab code do that?\n\nReply \n',
#   '\nI don’t think this is a deep learning problem, it sounds like straight linalg.\nI don’t have any examples that use matlab code sorry.\n\nReply \n',
#   '\nThanks\n\nReply \n',
#   '\ncan you provide the MLP algorithm for hand written digit classification using sklearn dataset?\n\nReply \n',
#   '\nYes, there are many on the blog, use the search box.\n\nReply \n',
#   '\nhi Sir, Hope u fine, my teacher said python is removed from the market in coming 10 year , is this reality in ur vision, and he said js will be the coming language in AI ,…what u think about it.\n\nReply \n',
#   '\nPerhaps ask your teacher why they think this and make up your own mind.\n\nReply \n',
#   '\n(base) C:\\Users\\226399\\Kerasprojects>python beach1.py\nData Type:uint8\nMin:0.000\nMax: 255.000\nAfter Normalization\nMin:0.000,Max:1.000\n\nReply \n',
#   '\nWell done!\n\nReply \n',
#   '\nThanks for sharing. Informative Article.\n\nReply \n',
#   '\nYou’re welcome.\n\nReply \n',
#   '\nHello Sir, i have tuned a model for facial emotion recognition and the highest accuracy so far is about 54% on average but i used ResNet50\ncould you help me how can i improve the accuracy ..\n\nReply \n',
#   '\nYes, see these suggestions:\nhttps://machinelearningmastery.com/start-here/#better\n\nReply \n',
#   '\nthank you so much\n\nReply \n',
#   '\nYou’re welcome!\n\nReply \n',
#   '\nHow do we cite your 2015 Extract Conference? How do we cite your useful comments? How do we cite extracts from slides you have used in conferences?\n\nReply \n',
#   '\nYou mean providing URLs?\n\nReply \n',
#   '\nFirst, I appreciate your blog; I have read your article carefully, Your content is very valuable to me. I hope people like this blog too. I hope you will gain more experience with your knowledge; That’s why people get more information.\n\nReply \n',
#   '\nVery good explanation.. Really appreciate the efforts!!!\nother people interested to learn more about data science can go to- learnbay.co\n\nReply \n',
#   '\nwow its such a great post! im really into digital world and learning been always the best method to keep me motivated. keep sharing ! i recently came to know Amritsar Digital Academy from here you can learn digital marketing course which is such a good and helpful course in today’s era! it worth trying.\n\nReply \n',
#   '\nThank you for the feedback, Deepika!\n\nReply \n',
#   '\nCan tell us about the deep learning interview questions?\n\nReply \n',
#   '\nHi Camila…the following looks like a great start:\nhttps://www.indeed.com/career-advice/interviewing/deep-learning-interview-questions\n\nReply \n',
#   '\nHi Dr. Jason, I have a dataset.\nit is a multi-class label classification, I want to apply Deep Neural networks, all the dataset features are probabilities, How can I prepare the data before applying the model. My question is Should I apply data normalization then build the model or do something else?\nThanks\nRegards!\n\nReply \n']}

# %%
data1=pd.DataFrame(data,columns=['Name','comments'])
data1
# Out:
#                  Name                                           comments
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 1      Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 3      Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4               Roman                               \nMe too\n\nReply \n
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
# [287 rows x 2 columns]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree

# %%
data1['clean_comment']= data1['comments'].apply(lambda x:remove_punctuation(x))
data1.head()
# Out:
#              Name                                           comments  \
# 0        Gibachan  \nIf the deep learning is such great algorithm...
# 1  Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2       Priyankar  \nCould you please give me some idea, how deep...
# 3  Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4           Roman                               \nMe too\n\nReply \n
#
#                                        clean_comment
# 0  \nIf the deep learning is such great algorithm...
# 1  \nI think that SVM and similar techniques stil...
# 2  \nCould you please give me some idea how deep ...
# 3  \nStart by defining your problem\nhttpmachinel...
# 4                               \nMe too\n\nReply \n

# %%
import re
def remove_new_line(text):
    return re.sub(r'(\n)',' ',text)

# %%
data1['clean_comment']=data1['clean_comment'].apply(lambda x:remove_new_line(x))

# %%
data1
# Out:
#                  Name                                           comments  \
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 1      Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 3      Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4               Roman                               \nMe too\n\nReply \n
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
#                                          clean_comment
# 0     If the deep learning is such great algorithm ...
# 1     I think that SVM and similar techniques still...
# 2     Could you please give me some idea how deep l...
# 3     Start by defining your problem httpmachinelea...
# 4                                      Me too  Reply
# ..                                                 ...
# 282   wow its such a great post im really into digi...
# 283        Thank you for the feedback Deepika  Reply
# 284   Can tell us about the deep learning interview...
# 285   Hi Camila…the following looks like a great st...
# 286   Hi Dr Jason I have a dataset it is a multicla...
#
# [287 rows x 3 columns]

# %%
def extra_space(text):
    return re.sub(r' +',' ',text)

# %%
data1['clean_comment']=data1['clean_comment'].apply(lambda x:extra_space(x))

# %%
data1
# Out:
#                  Name                                           comments  \
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 1      Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 3      Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4               Roman                               \nMe too\n\nReply \n
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
#                                          clean_comment
# 0     If the deep learning is such great algorithm ...
# 1     I think that SVM and similar techniques still...
# 2     Could you please give me some idea how deep l...
# 3     Start by defining your problem httpmachinelea...
# 4                                        Me too Reply
# ..                                                 ...
# 282   wow its such a great post im really into digi...
# 283          Thank you for the feedback Deepika Reply
# 284   Can tell us about the deep learning interview...
# 285   Hi Camila…the following looks like a great st...
# 286   Hi Dr Jason I have a dataset it is a multicla...
#
# [287 rows x 3 columns]

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data1['clean_comment']= data1['clean_comment'].apply(lambda x: nltk.word_tokenize(x))

# %%
data1
# Out:
#                  Name                                           comments  \
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 1      Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 3      Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4               Roman                               \nMe too\n\nReply \n
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
#                                          clean_comment
# 0    [If, the, deep, learning, is, such, great, alg...
# 1    [I, think, that, SVM, and, similar, techniques...
# 2    [Could, you, please, give, me, some, idea, how...
# 3    [Start, by, defining, your, problem, httpmachi...
# 4                                     [Me, too, Reply]
# ..                                                 ...
# 282  [wow, its, such, a, great, post, im, really, i...
# 283   [Thank, you, for, the, feedback, Deepika, Reply]
# 284  [Can, tell, us, about, the, deep, learning, in...
# 285  [Hi, Camila…the, following, looks, like, a, gr...
# 286  [Hi, Dr, Jason, I, have, a, dataset, it, is, a...
#
# [287 rows x 3 columns]

# %%
stopwords=nltk.corpus.stopwords.words('english')

# %%
def remove_stopWord(text):
    output=[i for i in text if i not in stopwords]
    return output

# %%
data1['clean_comment']=data1['clean_comment'].apply(lambda x: remove_stopWord(x))

# %%
data1
# Out:
#                  Name                                           comments  \
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 1      Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 3      Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4               Roman                               \nMe too\n\nReply \n
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
#                                          clean_comment
# 0    [If, deep, learning, great, algorithm, think, ...
# 1    [I, think, SVM, similar, techniques, still, pl...
# 2    [Could, please, give, idea, deep, learning, ap...
# 3    [Start, defining, problem, httpmachinelearning...
# 4                                          [Me, Reply]
# ..                                                 ...
# 282  [wow, great, post, im, really, digital, world,...
# 283                  [Thank, feedback, Deepika, Reply]
# 284  [Can, tell, us, deep, learning, interview, que...
# 285  [Hi, Camila…the, following, looks, like, great...
# 286  [Hi, Dr, Jason, I, dataset, multiclass, label,...
#
# [287 rows x 3 columns]

# %%
from nltk.stem import WordNetLemmatizer
wordnet= WordNetLemmatizer()

# %%
def lemmatizer(text):
    lemm_text = [wordnet.lemmatize(word) for word in text]
    return lemm_text

# %%
data1['clean_comment']=data1['clean_comment'].apply(lambda x: lemmatizer(x))

# %%
data1
# Out:
#                  Name                                           comments  \
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 1      Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 3      Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4               Roman                               \nMe too\n\nReply \n
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
#                                          clean_comment
# 0    [If, deep, learning, great, algorithm, think, ...
# 1    [I, think, SVM, similar, technique, still, pla...
# 2    [Could, please, give, idea, deep, learning, ap...
# 3    [Start, defining, problem, httpmachinelearning...
# 4                                          [Me, Reply]
# ..                                                 ...
# 282  [wow, great, post, im, really, digital, world,...
# 283                  [Thank, feedback, Deepika, Reply]
# 284  [Can, tell, u, deep, learning, interview, ques...
# 285  [Hi, Camila…the, following, look, like, great,...
# 286  [Hi, Dr, Jason, I, dataset, multiclass, label,...
#
# [287 rows x 3 columns]

# %%
data1
# Out:
#                  Name                                           comments  \
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 1      Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 3      Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4               Roman                               \nMe too\n\nReply \n
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
#                                          clean_comment
# 0    [If, deep, learning, great, algorithm, think, ...
# 1    [I, think, SVM, similar, technique, still, pla...
# 2    [Could, please, give, idea, deep, learning, ap...
# 3    [Start, defining, problem, httpmachinelearning...
# 4                                          [Me, Reply]
# ..                                                 ...
# 282  [wow, great, post, im, really, digital, world,...
# 283                  [Thank, feedback, Deepika, Reply]
# 284  [Can, tell, u, deep, learning, interview, ques...
# 285  [Hi, Camila…the, following, look, like, great,...
# 286  [Hi, Dr, Jason, I, dataset, multiclass, label,...
#
# [287 rows x 3 columns]

# %%
data1['lemmatized'] = data1.clean_comment.apply(lambda x: ' '.join(x))

# %%
#nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import tokenize
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer, SentimentIntensityAnalyzer
from nltk.sentiment.util import *

#sci-kit learn
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
nltk.download('stopwords')
stop = stopwords.words('english')
from nltk.stem import WordNetLemmatizer
wordnet= WordNetLemmatizer()
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree

# %%
def lower(text):
    return text.lower()

# %%
def tokenization(text):
    tokens =  nltk.word_tokenize(text)
    return tokens

# %%
def remove_stopWord(text):
    output=[i for i in text if i not in stop]
    return output

# %%
def lemmatizer(words):
    return [wordnet.lemmatize(word) for word in words]

# %%
def preprocess(text):
    text1=remove_punctuation(text)
    text2=lower(text1)
    word=tokenization(text2)
    words=remove_stopWord(word)
    final=lemmatizer(words)
    return final

# %%
data=pd.read_csv('IMDB Dataset.csv')

# %%
data["review"]=data["review"].apply(lambda x: preprocess(x))

# %%
import inflect
def replace_numbers(text):
    p = inflect.engine()
    new_words = []
    for word in text:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

# %%
data["review"]=data["review"].apply(lambda x:replace_numbers(x))

# %%
data['lemmatized'] = data.review.apply(lambda x: ' '.join(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report

# %%
tfidf=TfidfVectorizer(max_features=10000)

# %%
x=data["lemmatized"]
y=data["sentiment"]

# %%
x=tfidf.fit_transform(x)

# %%
clf=LinearSVC()

# %%
clf.fit(x,y)
# Out:
# LinearSVC()

# %%
tf=data1["lemmatized"]

# %%
vc=tfidf.transform(tf)

# %%
y_pred=clf.predict(vc)

# %%
y_pred
# Out:
# array(['positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'negative', 'positive',
#        'positive', 'negative', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'negative', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'negative', 'positive',
#        'positive', 'positive', 'positive', 'negative', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'negative', 'positive', 'negative', 'negative', 'negative',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'negative', 'positive', 'negative', 'negative',
#        'positive', 'positive', 'positive', 'positive', 'negative',
#        'positive', 'positive', 'positive', 'positive', 'negative',
#        'positive', 'positive', 'positive', 'negative', 'negative',
#        'positive', 'negative', 'positive', 'negative', 'positive',
#        'positive', 'positive', 'positive', 'negative', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'negative', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'negative', 'negative',
#        'positive', 'negative', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'negative', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'negative', 'positive', 'positive',
#        'negative', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'negative', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'negative', 'positive', 'negative',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'negative', 'negative', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'negative', 'negative',
#        'positive', 'positive', 'positive', 'negative', 'positive',
#        'positive', 'negative', 'positive', 'negative', 'positive',
#        'positive', 'positive', 'negative', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'negative',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'negative', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'negative', 'negative', 'positive', 'positive', 'positive',
#        'negative', 'negative', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'negative', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'negative', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'negative', 'positive', 'negative',
#        'positive', 'negative', 'positive', 'negative', 'positive',
#        'positive', 'positive', 'negative', 'positive', 'positive',
#        'negative', 'positive', 'positive', 'negative', 'negative',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'negative', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'negative'], dtype=object)

# %%
data2=pd.DataFrame(y_pred)
data2
# Out:
#             0
# 0    positive
# 1    positive
# 2    positive
# 3    positive
# 4    positive
# ..        ...
# 282  positive
# 283  positive
# 284  positive
# 285  positive
# 286  negative
#
# [287 rows x 1 columns]

# %%
data = pd.concat([data1, data2], axis=1)
data
# Out:
#                  Name                                           comments  \
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 1      Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 3      Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4               Roman                               \nMe too\n\nReply \n
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
#                                          clean_comment  \
# 0    [If, deep, learning, great, algorithm, think, ...
# 1    [I, think, SVM, similar, technique, still, pla...
# 2    [Could, please, give, idea, deep, learning, ap...
# 3    [Start, defining, problem, httpmachinelearning...
# 4                                          [Me, Reply]
# ..                                                 ...
# 282  [wow, great, post, im, really, digital, world,...
# 283                  [Thank, feedback, Deepika, Reply]
# 284  [Can, tell, u, deep, learning, interview, ques...
# 285  [Hi, Camila…the, following, look, like, great,...
# 286  [Hi, Dr, Jason, I, dataset, multiclass, label,...
#
#                                             lemmatized         0
# 0    If deep learning great algorithm think older a...  positive
# 1    I think SVM similar technique still place It s...  positive
# 2    Could please give idea deep learning applied s...  positive
# 3    Start defining problem httpmachinelearningmast...  positive
# 4                                             Me Reply  positive
# ..                                                 ...       ...
# 282  wow great post im really digital world learnin...  positive
# 283                       Thank feedback Deepika Reply  positive
# 284  Can tell u deep learning interview question Reply  positive
# 285  Hi Camila…the following look like great start ...  positive
# 286  Hi Dr Jason I dataset multiclass label classif...  negative
#
# [287 rows x 5 columns]

# %%
data.columns.values[4] = "sentiment"

# %%
data
# Out:
#                  Name                                           comments  \
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 1      Jason Brownlee  \nI think that SVM and similar techniques stil...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 3      Jason Brownlee  \nStart by defining your problem:\nhttp://mach...
# 4               Roman                               \nMe too\n\nReply \n
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
#                                          clean_comment  \
# 0    [If, deep, learning, great, algorithm, think, ...
# 1    [I, think, SVM, similar, technique, still, pla...
# 2    [Could, please, give, idea, deep, learning, ap...
# 3    [Start, defining, problem, httpmachinelearning...
# 4                                          [Me, Reply]
# ..                                                 ...
# 282  [wow, great, post, im, really, digital, world,...
# 283                  [Thank, feedback, Deepika, Reply]
# 284  [Can, tell, u, deep, learning, interview, ques...
# 285  [Hi, Camila…the, following, look, like, great,...
# 286  [Hi, Dr, Jason, I, dataset, multiclass, label,...
#
#                                             lemmatized sentiment
# 0    If deep learning great algorithm think older a...  positive
# 1    I think SVM similar technique still place It s...  positive
# 2    Could please give idea deep learning applied s...  positive
# 3    Start defining problem httpmachinelearningmast...  positive
# 4                                             Me Reply  positive
# ..                                                 ...       ...
# 282  wow great post im really digital world learnin...  positive
# 283                       Thank feedback Deepika Reply  positive
# 284  Can tell u deep learning interview question Reply  positive
# 285  Hi Camila…the following look like great start ...  positive
# 286  Hi Dr Jason I dataset multiclass label classif...  negative
#
# [287 rows x 5 columns]

# %%
data['Name'].value_counts()
# Out:
# Jason Brownlee    133
# Izzy                4
# naivebae            3
# arif                3
# Hazem               3
#                  ...
# Cathy               1
# mhamed kassem       1
# jayaram             1
# mera                1
# Fatima              1
# Name: Name, Length: 130, dtype: int64

# %%
data = data[data.Name != 'Jason Brownlee']

# %%
data
# Out:
#                  Name                                           comments  \
# 0            Gibachan  \nIf the deep learning is such great algorithm...
# 2           Priyankar  \nCould you please give me some idea, how deep...
# 4               Roman                               \nMe too\n\nReply \n
# 5                  sk  \ncan you tell what could be research for MS l...
# 7                Rita  \nif I want to reconstruct 3D object, which is...
# ..                ...                                                ...
# 282           deepika  \nwow its such a great post! im really into di...
# 283  James Carmichael  \nThank you for the feedback, Deepika!\n\nRepl...
# 284            Camila  \nCan tell us about the deep learning intervie...
# 285  James Carmichael  \nHi Camila…the following looks like a great s...
# 286            Fatima  \nHi Dr. Jason, I have a dataset.\nit is a mul...
#
#                                          clean_comment  \
# 0    [If, deep, learning, great, algorithm, think, ...
# 2    [Could, please, give, idea, deep, learning, ap...
# 4                                          [Me, Reply]
# 5    [tell, could, research, MS, level, deep, learn...
# 7    [I, want, reconstruct, 3D, object, better, ANN...
# ..                                                 ...
# 282  [wow, great, post, im, really, digital, world,...
# 283                  [Thank, feedback, Deepika, Reply]
# 284  [Can, tell, u, deep, learning, interview, ques...
# 285  [Hi, Camila…the, following, look, like, great,...
# 286  [Hi, Dr, Jason, I, dataset, multiclass, label,...
#
#                                             lemmatized sentiment
# 0    If deep learning great algorithm think older a...  positive
# 2    Could please give idea deep learning applied s...  positive
# 4                                             Me Reply  positive
# 5     tell could research MS level deep learning Reply  positive
# 7    I want reconstruct 3D object better ANN CNN de...  positive
# ..                                                 ...       ...
# 282  wow great post im really digital world learnin...  positive
# 283                       Thank feedback Deepika Reply  positive
# 284  Can tell u deep learning interview question Reply  positive
# 285  Hi Camila…the following look like great start ...  positive
# 286  Hi Dr Jason I dataset multiclass label classif...  negative
#
# [154 rows x 5 columns]
