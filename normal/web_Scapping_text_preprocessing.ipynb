# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url="https://alchemy-bd.com"

# %%
page=requests.get(url)

# %%
text=page.content

# %%
text
# Out:
# b'<!doctype html>\r\n<html lang="en">\r\n<head>\r\n    <meta charset="UTF-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\r\n    <title>Alchemy Software | Artificier For Animating Your Aspiration</title>\r\n    <link rel="shortcut icon" href="https://alchemy-bd.com/wp-content/themes/alchemy/favicon.ico"/>\r\n    <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/bootstrap.min.css" rel="stylesheet"/>\r\n\r\n\r\n    <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/font-awesome.min.css" rel="stylesheet"/>\r\n    <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/sweet-alert.css" rel="stylesheet"/>\r\n    <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/animate.css" rel="stylesheet"/>\r\n\r\n    <link rel="stylesheet" href="https://alchemy-bd.com/wp-content/themes/alchemy/owl-carousel/owl.carousel.css">\r\n    <link rel="stylesheet" href="https://alchemy-bd.com/w
# ...

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

# %%
import re
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)

# %%
def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    return text

# %%
sample = denoise_text(text)
print(sample)
# Out:
# Alchemy Software | Artificier For Animating Your Aspiration
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Alchemy Software Limited
#
#
#                         Artificer For Animating Your Aspiration
#
#
#
#
#
# HomeAbout Us
# Portfolio
# Career
# News
# Contact
#
#
#
#
#   Sales: +88 01313 406 600
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Product Name: Restaurant Management Software
#
# Description: We have 3 different versions for
# ...

# %%
import contractions
def replace_contractions(text):
    """Replace contractions in string of text"""
    return contractions.fix(text)

sample_1 = replace_contractions(sample)
print(sample_1)
# Out:
# Alchemy Software | Artificier For Animating Your Aspiration
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Alchemy Software Limited
#
#
#                         Artificer For Animating Your Aspiration
#
#
#
#
#
# HomeAbout Us
# Portfolio
# Career
# News
# Contact
#
#
#
#
#   Sales: +88 01313 406 600
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Product Name: Restaurant Management Software
#
# Description: We have 3 different versions for
# ...

# %%
import string
def replace_contractions(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree

sample_2 = replace_contractions(sample_1)
print(sample_2)
# Out:
# Alchemy Software  Artificier For Animating Your Aspiration
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Alchemy Software Limited
#
#
#                         Artificer For Animating Your Aspiration
#
#
#
#
#
# HomeAbout Us
# Portfolio
# Career
# News
# Contact
#
#
#
#
#   Sales 88 01313 406 600
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Product Name Restaurant Management Software
#
# Description We have 3 different versions for
# ...

# %%
def replace_space(text):
    return re.sub(r' +',' ',text)
sample_3=replace_space(sample_2)
print(sample_3)
# Out:
# Alchemy Software Artificier For Animating Your Aspiration
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Alchemy Software Limited
#
#
#  Artificer For Animating Your Aspiration
#
#
#
#
#
# HomeAbout Us
# Portfolio
# Career
# News
# Contact
#
#
#
#
#  Sales 88 01313 406 600
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Product Name Restaurant Management Software
#
# Description We have 3 different versions for
# ...

# %%
import nltk
words = nltk.word_tokenize(sample_3)
print(words)
# Out:
# ['Alchemy', 'Software', 'Artificier', 'For', 'Animating', 'Your', 'Aspiration', 'Alchemy', 'Software', 'Limited', 'Artificer', 'For', 'Animating', 'Your', 'Aspiration', 'HomeAbout', 'Us', 'Portfolio', 'Career', 'News', 'Contact', 'Sales', '88', '01313', '406', '600', 'Product', 'Name', 'Restaurant', 'Management', 'Software', 'Description', 'We', 'have', '3', 'different', 'versions', 'for', 'Restaurant', 'Management', 'software', 'so', 'that', 'valued', 'customer', 'can', 'choose', 'suitable', 'one', 'from', 'the', 'variety', 'You', 'can', 'manage', 'every', 'necessary', 'work', 'like', 'customer', 'billing', 'daily', 'collection', 'cash', 'card', 'wise', 'mgt', 'due', 'mgt', 'table', 'wise', 'reporting', 'and', 'efficient', 'stock', 'mgt', 'various', 'reporting', 'etc', 'many', 'more', 'with', 'this', 'software', 'Side', 'by', 'side', 'you', 'can', 'get', 'Restaurant', 'cash', 'bank', 'ledger', 'book', 'receipt', 'payment', 'income', 'statement', 'balance', 'sheet', 'and', 'necessary
# ...

# %%
import unicodedata
def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

# %%
words =  remove_non_ascii(words)
print(words)
# Out:
# ['Alchemy', 'Software', 'Artificier', 'For', 'Animating', 'Your', 'Aspiration', 'Alchemy', 'Software', 'Limited', 'Artificer', 'For', 'Animating', 'Your', 'Aspiration', 'HomeAbout', 'Us', 'Portfolio', 'Career', 'News', 'Contact', 'Sales', '88', '01313', '406', '600', 'Product', 'Name', 'Restaurant', 'Management', 'Software', 'Description', 'We', 'have', '3', 'different', 'versions', 'for', 'Restaurant', 'Management', 'software', 'so', 'that', 'valued', 'customer', 'can', 'choose', 'suitable', 'one', 'from', 'the', 'variety', 'You', 'can', 'manage', 'every', 'necessary', 'work', 'like', 'customer', 'billing', 'daily', 'collection', 'cash', 'card', 'wise', 'mgt', 'due', 'mgt', 'table', 'wise', 'reporting', 'and', 'efficient', 'stock', 'mgt', 'various', 'reporting', 'etc', 'many', 'more', 'with', 'this', 'software', 'Side', 'by', 'side', 'you', 'can', 'get', 'Restaurant', 'cash', 'bank', 'ledger', 'book', 'receipt', 'payment', 'income', 'statement', 'balance', 'sheet', 'and', 'necessary
# ...

# %%
def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

# %%
words =  to_lowercase(words)
print(words)
# Out:
# ['alchemy', 'software', 'artificier', 'for', 'animating', 'your', 'aspiration', 'alchemy', 'software', 'limited', 'artificer', 'for', 'animating', 'your', 'aspiration', 'homeabout', 'us', 'portfolio', 'career', 'news', 'contact', 'sales', '88', '01313', '406', '600', 'product', 'name', 'restaurant', 'management', 'software', 'description', 'we', 'have', '3', 'different', 'versions', 'for', 'restaurant', 'management', 'software', 'so', 'that', 'valued', 'customer', 'can', 'choose', 'suitable', 'one', 'from', 'the', 'variety', 'you', 'can', 'manage', 'every', 'necessary', 'work', 'like', 'customer', 'billing', 'daily', 'collection', 'cash', 'card', 'wise', 'mgt', 'due', 'mgt', 'table', 'wise', 'reporting', 'and', 'efficient', 'stock', 'mgt', 'various', 'reporting', 'etc', 'many', 'more', 'with', 'this', 'software', 'side', 'by', 'side', 'you', 'can', 'get', 'restaurant', 'cash', 'bank', 'ledger', 'book', 'receipt', 'payment', 'income', 'statement', 'balance', 'sheet', 'and', 'necessary
# ...

# %%
def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

# %%
words = remove_punctuation(words)
print(words)
# Out:
# ['alchemy', 'software', 'artificier', 'for', 'animating', 'your', 'aspiration', 'alchemy', 'software', 'limited', 'artificer', 'for', 'animating', 'your', 'aspiration', 'homeabout', 'us', 'portfolio', 'career', 'news', 'contact', 'sales', '88', '01313', '406', '600', 'product', 'name', 'restaurant', 'management', 'software', 'description', 'we', 'have', '3', 'different', 'versions', 'for', 'restaurant', 'management', 'software', 'so', 'that', 'valued', 'customer', 'can', 'choose', 'suitable', 'one', 'from', 'the', 'variety', 'you', 'can', 'manage', 'every', 'necessary', 'work', 'like', 'customer', 'billing', 'daily', 'collection', 'cash', 'card', 'wise', 'mgt', 'due', 'mgt', 'table', 'wise', 'reporting', 'and', 'efficient', 'stock', 'mgt', 'various', 'reporting', 'etc', 'many', 'more', 'with', 'this', 'software', 'side', 'by', 'side', 'you', 'can', 'get', 'restaurant', 'cash', 'bank', 'ledger', 'book', 'receipt', 'payment', 'income', 'statement', 'balance', 'sheet', 'and', 'necessary
# ...

# %%
import inflect
def replace_numbers(words):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

# %%
words = replace_numbers(words)
print(words)
# Out:
# ['alchemy', 'software', 'artificier', 'for', 'animating', 'your', 'aspiration', 'alchemy', 'software', 'limited', 'artificer', 'for', 'animating', 'your', 'aspiration', 'homeabout', 'us', 'portfolio', 'career', 'news', 'contact', 'sales', 'eighty-eight', 'one thousand, three hundred and thirteen', 'four hundred and six', 'six hundred', 'product', 'name', 'restaurant', 'management', 'software', 'description', 'we', 'have', 'three', 'different', 'versions', 'for', 'restaurant', 'management', 'software', 'so', 'that', 'valued', 'customer', 'can', 'choose', 'suitable', 'one', 'from', 'the', 'variety', 'you', 'can', 'manage', 'every', 'necessary', 'work', 'like', 'customer', 'billing', 'daily', 'collection', 'cash', 'card', 'wise', 'mgt', 'due', 'mgt', 'table', 'wise', 'reporting', 'and', 'efficient', 'stock', 'mgt', 'various', 'reporting', 'etc', 'many', 'more', 'with', 'this', 'software', 'side', 'by', 'side', 'you', 'can', 'get', 'restaurant', 'cash', 'bank', 'ledger', 'book', 'receipt
# ...

# %%
from nltk.corpus import stopwords
def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in stopwords.words('english'):
            new_words.append(word)
    return new_words

# %%
words = remove_stopwords(words)
print(words)
# Out:
# ['alchemy', 'software', 'artificier', 'animating', 'aspiration', 'alchemy', 'software', 'limited', 'artificer', 'animating', 'aspiration', 'homeabout', 'us', 'portfolio', 'career', 'news', 'contact', 'sales', 'eighty-eight', 'one thousand, three hundred and thirteen', 'four hundred and six', 'six hundred', 'product', 'name', 'restaurant', 'management', 'software', 'description', 'three', 'different', 'versions', 'restaurant', 'management', 'software', 'valued', 'customer', 'choose', 'suitable', 'one', 'variety', 'manage', 'every', 'necessary', 'work', 'like', 'customer', 'billing', 'daily', 'collection', 'cash', 'card', 'wise', 'mgt', 'due', 'mgt', 'table', 'wise', 'reporting', 'efficient', 'stock', 'mgt', 'various', 'reporting', 'etc', 'many', 'software', 'side', 'side', 'get', 'restaurant', 'cash', 'bank', 'ledger', 'book', 'receipt', 'payment', 'income', 'statement', 'balance', 'sheet', 'necessary', 'option', 'get', 'adequate', 'information', 'financial', 'performance', 'position'
# ...

# %%
from nltk.stem import WordNetLemmatizer
def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

# %%
words = lemmatize_verbs(words)
print(words)
# Out:
# ['alchemy', 'software', 'artificier', 'animate', 'aspiration', 'alchemy', 'software', 'limit', 'artificer', 'animate', 'aspiration', 'homeabout', 'us', 'portfolio', 'career', 'news', 'contact', 'sales', 'eighty-eight', 'one thousand, three hundred and thirteen', 'four hundred and six', 'six hundred', 'product', 'name', 'restaurant', 'management', 'software', 'description', 'three', 'different', 'versions', 'restaurant', 'management', 'software', 'value', 'customer', 'choose', 'suitable', 'one', 'variety', 'manage', 'every', 'necessary', 'work', 'like', 'customer', 'bill', 'daily', 'collection', 'cash', 'card', 'wise', 'mgt', 'due', 'mgt', 'table', 'wise', 'report', 'efficient', 'stock', 'mgt', 'various', 'report', 'etc', 'many', 'software', 'side', 'side', 'get', 'restaurant', 'cash', 'bank', 'ledger', 'book', 'receipt', 'payment', 'income', 'statement', 'balance', 'sheet', 'necessary', 'option', 'get', 'adequate', 'information', 'financial', 'performance', 'position', 'business', 'n
# ...

# %% [markdown]
# # another way

# %%
 soup = BeautifulSoup(text, "html.parser")

# %%
text=soup.find(attrs={'class': 'col-md-9'}).text
text
# Out:
# '\nWho we are?\nAlchemy Software is a growing IT service provider of high-end business solutions to clients across the globe. Over the years, the company extended the range of its services in various industries. As a software development company with a deep understanding of values and commitment, Alchemy Software believes that real profit for any business is the goodwill and it doesn’t come without customer’s satisfaction. Based on that philosophy, Alchemy Software devoted its full effort on customer satisfaction by providing standard software solutions. In combine cutting edged technology, merit, and innovation are three strengths for creating something extraordinary.\n'

# %%
text=soup.find(attrs={'class': 'col-md-9'}).text.replace('\n','')
text
# Out:
# 'Who we are?Alchemy Software is a growing IT service provider of high-end business solutions to clients across the globe. Over the years, the company extended the range of its services in various industries. As a software development company with a deep understanding of values and commitment, Alchemy Software believes that real profit for any business is the goodwill and it doesn’t come without customer’s satisfaction. Based on that philosophy, Alchemy Software devoted its full effort on customer satisfaction by providing standard software solutions. In combine cutting edged technology, merit, and innovation are three strengths for creating something extraordinary.'

# %%
web="https://www.daraz.com.bd/televisions/?spm=a2a0e.home.cate_3.1.573712f7M7Orwb"

# %%
text1
# Out:
# b'<!doctype html>\r\n<html lang="en">\r\n<head>\r\n    <meta charset="UTF-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\r\n    <title>Alchemy Software | Artificier For Animating Your Aspiration</title>\r\n    <link rel="shortcut icon" href="https://alchemy-bd.com/wp-content/themes/alchemy/favicon.ico"/>\r\n    <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/bootstrap.min.css" rel="stylesheet"/>\r\n\r\n\r\n    <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/font-awesome.min.css" rel="stylesheet"/>\r\n    <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/sweet-alert.css" rel="stylesheet"/>\r\n    <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/animate.css" rel="stylesheet"/>\r\n\r\n    <link rel="stylesheet" href="https://alchemy-bd.com/wp-content/themes/alchemy/owl-carousel/owl.carousel.css">\r\n    <link rel="stylesheet" href="https://alchemy-bd.com/w
# ...

# %%
soup = BeautifulSoup(text1, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <title>Alchemy Software | Artificier For Animating Your Aspiration</title>
# <link href="https://alchemy-bd.com/wp-content/themes/alchemy/favicon.ico" rel="shortcut icon"/>
# <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/sweet-alert.css" rel="stylesheet"/>
# <link href="https://alchemy-bd.com/wp-content/themes/alchemy/css/animate.css" rel="stylesheet"/>
# <link href="https://alchemy-bd.com/wp-content/themes/alchemy/owl-carousel/owl.carousel.css" rel="stylesheet"/>
# <link href="https://alchemy-bd.com/wp-content/themes/alchemy/owl-carousel/owl.theme.css" rel="stylesheet"/>
# ...
